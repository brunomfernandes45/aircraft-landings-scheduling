# %%
def read_data_from_file(filename):
    """
    Reads data from a file with the specified format for an air traffic scheduling problem.

    Args:
        filename (str): The path to the data file.

    Returns:
        tuple: A tuple containing the parsed data:
            - num_planes (int): The number of planes.
            - freeze_time (int): The freeze time.
            - planes_data (list): A list of dictionaries, where each dictionary contains
              the data for a plane.
            - separation_times (list of lists): A 2D list of separation times.
    """
    try:
        with open(filename, "r") as f:
            # Read the first line: number of planes and freeze time
            first_line = f.readline().strip().split()
            num_planes = int(first_line[0])
            freeze_time = int(first_line[1])

            planes_data = []
            separation_times = []
            
            for _ in range(num_planes):
                line = f.readline().strip().split()
                appearance_time = int(line[0])
                earliest_landing_time = int(line[1])
                target_landing_time = int(line[2])
                latest_landing_time = int(line[3])
                penalty_early = float(line[4])
                penalty_late = float(line[5])
                planes_data.append(
                    {
                        "appearance_time": appearance_time,
                        "earliest_landing_time": earliest_landing_time,
                        "target_landing_time": target_landing_time,
                        "latest_landing_time": latest_landing_time,
                        "penalty_early": penalty_early,
                        "penalty_late": penalty_late,
                    }
                )
                
                separation_row = []
                while len(separation_row) < num_planes:
                    line = f.readline().strip().split()
                    separation_row.extend([int(x) for x in line])

                separation_times.append(separation_row)

        return num_planes, freeze_time, planes_data, separation_times

    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None, None, None, None
    except ValueError:
        print(f"Error: Error reading data in file '{filename}'.")
        return None, None, None, None

# %%
filename = "data/airland13.txt"

num_planes, freeze_time, planes_data, separation_times = read_data_from_file(filename)

if num_planes is not None:
    print("Number of planes:", num_planes)
    print("Freeze time:", freeze_time)
    print("\nPlane data:")
    for i, plane in enumerate(planes_data):
        print(f"Plane {i+1}: {plane}")
    print("\nSeparation times:")
    for i, row in enumerate(separation_times):
        print(f"After plane {i+1}: {row}")
# Out:
# Number of planes: 500
# Freeze time: 720
#
# Plane data:
# Plane 1: {'appearance_time': 1, 'earliest_landing_time': 601, 'target_landing_time': 709, 'latest_landing_time': 2401, 'penalty_early': 1.7, 'penalty_late': 1.9}
# Plane 2: {'appearance_time': 420, 'earliest_landing_time': 1020, 'target_landing_time': 1298, 'latest_landing_time': 2820, 'penalty_early': 1.19, 'penalty_late': 1.27}
# Plane 3: {'appearance_time': 429, 'earliest_landing_time': 1029, 'target_landing_time': 1574, 'latest_landing_time': 2829, 'penalty_early': 1.13, 'penalty_late': 1.88}
# Plane 4: {'appearance_time': 493, 'earliest_landing_time': 1093, 'target_landing_time': 1504, 'latest_landing_time': 2893, 'penalty_early': 1.86, 'penalty_late': 1.14}
# Plane 5: {'appearance_time': 704, 'earliest_landing_time': 1304, 'target_landing_time': 1400, 'latest_landing_time': 3104, 'penalty_early': 1.57, 'penalty_late': 1.93}
# Plane 6: {'appearance_time': 734, 'earliest_landing_time': 1334, 'target_landing_time': 1414, 'latest_landing_time': 3134, 'penalty_early': 1.29, 'penalty_late': 1.34}
# Plane 7: {'appearance_time': 1031, 'earliest_landing_time': 1631, 'target_landing_time': 1836, 'latest_landing_time': 3431, 'penalty_early': 1.19, 'penalty_late': 1.34}
# Plane 8: {'appearance_time': 1125, 'earliest_landing_time': 1725, 'target_landing_time': 2316, 'latest_landing_time': 3525, 'penalty_early': 1.7, 'penalty_late': 1.26}
# Plane 9: {'appearance_time': 1248, 'earliest_landing_time': 1848, 'target_landing_time': 2385, 'latest_landing_time': 3648, 'penalty_early': 1.95, 'penalty_late': 1.08}
# Plane 10: {'appearance_time': 1289, 'earliest_landing_time': 1889, 'target_landing_time': 2133, 'latest_landing_time': 3689, 'penalty_early': 1.21, 'penalty_late': 1.67}
# Plane 11: {'appearance_time': 1590, 'earliest_landing_time': 2190, 'target_landing_time': 2368, 'latest_landing_time': 3990, 'penalty_early': 1.42, 'penalty_late': 1.06}
# Plane 12: {'appearance_time': 1745, 'earliest_landing_time': 2345, 'target_landing_time': 2651, 'latest_landing_time': 4145, 'penalty_early': 1.45, 'penalty_late': 1.82}
# Plane 13: {'appearance_time': 1806, 'earliest_landing_time': 2406, 'target_landing_time': 2947, 'latest_landing_time': 4206, 'penalty_early': 1.98, 'penalty_late': 1.78}
# Plane 14: {'appearance_time': 1834, 'earliest_landing_time': 2434, 'target_landing_time': 2571, 'latest_landing_time': 4234, 'penalty_early': 1.36, 'penalty_late': 1.5}
# Plane 15: {'appearance_time': 1866, 'earliest_landing_time': 2466, 'target_landing_time': 3064, 'latest_landing_time': 4266, 'penalty_early': 1.06, 'penalty_late': 1.89}
# Plane 16: {'appearance_time': 1941, 'earliest_landing_time': 2541, 'target_landing_time': 2946, 'latest_landing_time': 4341, 'penalty_early': 1.81, 'penalty_late': 1.72}
# Plane 17: {'appearance_time': 2031, 'earliest_landing_time': 2631, 'target_landing_time': 2931, 'latest_landing_time': 4431, 'penalty_early': 1.36, 'penalty_late': 1.88}
# Plane 18: {'appearance_time': 2037, 'earliest_landing_time': 2637, 'target_landing_time': 3075, 'latest_landing_time': 4437, 'penalty_early': 1.03, 'penalty_late': 1.84}
# Plane 19: {'appearance_time': 2250, 'earliest_landing_time': 2850, 'target_landing_time': 3174, 'latest_landing_time': 4650, 'penalty_early': 1.21, 'penalty_late': 1.47}
# Plane 20: {'appearance_time': 2404, 'earliest_landing_time': 3004, 'target_landing_time': 3201, 'latest_landing_time': 4804, 'penalty_early': 1.81, 'penalty_late': 1.85}
# Plane 21: {'appearance_time': 2562, 'earliest_landing_time': 3162, 'target_landing_time': 3323, 'latest_landing_time': 4962, 'penalty_early': 1.61, 'penalty_late': 1.4}
# Plane 22: {'appearance_time': 2587, 'earliest_landing_time': 3187, 'target_landing_time': 3680, 'latest_landing_time': 4987, 'penalty_early': 1.83, 'penalty_late': 1.03}
# Plane 23: {'appearance_time': 2618, 'earliest_landing_time': 3218, 'target_landing_time': 3752, 'latest_landing_time': 5018, 'penalty_early': 1.74, 'penalty_late': 1.96}
# Plane 24: {'appearance_time': 2760, 'earliest_landing_time': 3360, 'target_landing_time': 3683, 'latest_landing_time': 5160, 'penalty_early': 1.44, 'penalty_late': 1.98}
# Plane 25: {'appearance_time': 2824, 'earliest_landing_time': 3424, 'target_landing_time': 3675, 'latest_landing_time': 5224, 'penalty_early': 1.91, 'penalty_late': 1.28}
# Plane 26: {'appearance_time': 2915, 'earliest_landing_time': 3515, 'target_landing_time': 3847, 'latest_landing_time': 5315, 'penalty_early': 1.66, 'penalty_late': 1.02}
# Plane 27: {'appearance_time': 3098, 'earliest_landing_time': 3698, 'target_landing_time': 4113, 'latest_landing_time': 5498, 'penalty_early': 1.09, 'penalty_late': 1.84}
# Plane 28: {'appearance_time': 3117, 'earliest_landing_time': 3717, 'target_landing_time': 4027, 'latest_landing_time': 5517, 'penalty_early': 1.57, 'penalty_late': 1.54}
# Plane 29: {'appearance_time': 3229, 'earliest_landing_time': 3829, 'target_landing_time': 4310, 'latest_landing_time': 5629, 'penalty_early': 1.29, 'penalty_late': 1.79}
# Plane 30: {'appearance_time': 3412, 'earliest_landing_time': 4012, 'target_landing_time': 4254, 'latest_landing_time': 5812, 'penalty_early': 1.07, 'penalty_late': 1.93}
# Plane 31: {'appearance_time': 3496, 'earliest_landing_time': 4096, 'target_landing_time': 4231, 'latest_landing_time': 5896, 'penalty_early': 1.52, 'penalty_late': 1.71}
# Plane 32: {'appearance_time': 3793, 'earliest_landing_time': 4393, 'target_landing_time': 4662, 'latest_landing_time': 6193, 'penalty_early': 1.59, 'penalty_late': 1.7}
# Plane 33: {'appearance_time': 3911, 'earliest_landing_time': 4511, 'target_landing_time': 4964, 'latest_landing_time': 6311, 'penalty_early': 1.72, 'penalty_late': 1.41}
# Plane 34: {'appearance_time': 4075, 'earliest_landing_time': 4675, 'target_landing_time': 4761, 'latest_landing_time': 6475, 'penalty_early': 1.9, 'penalty_late': 1.57}
# Plane 35: {'appearance_time': 4342, 'earliest_landing_time': 4942, 'target_landing_time': 5283, 'latest_landing_time': 6742, 'penalty_early': 1.38, 'penalty_late': 1.62}
# Plane 36: {'appearance_time': 4553, 'earliest_landing_time': 5153, 'target_landing_time': 5419, 'latest_landing_time': 6953, 'penalty_early': 1.64, 'penalty_late': 1.29}
# Plane 37: {'appearance_time': 4570, 'earliest_landing_time': 5170, 'target_landing_time': 5714, 'latest_landing_time': 6970, 'penalty_early': 1.35, 'penalty_late': 1.22}
# Plane 38: {'appearance_time': 4578, 'earliest_landing_time': 5178, 'target_landing_time': 5363, 'latest_landing_time': 6978, 'penalty_early': 1.53, 'penalty_late': 1.77}
# Plane 39: {'appearance_time': 4591, 'earliest_landing_time': 5191, 'target_landing_time': 5618, 'latest_landing_time': 6991, 'penalty_early': 1.16, 'penalty_late': 1.84}
# Plane 40: {'appearance_time': 4751, 'earliest_landing_time': 5351, 'target_landing_time': 5688, 'latest_landing_time': 7151, 'penalty_early': 1.87, 'penalty_late': 1.85}
# Plane 41: {'appearance_time': 4922, 'earliest_landing_time': 5522, 'target_landing_time': 5658, 'latest_landing_time': 7322, 'penalty_early': 1.05, 'penalty_late': 1.63}
# Plane 42: {'appearance_time': 5042, 'earliest_landing_time': 5642, 'target_landing_time': 5967, 'latest_landing_time': 7442, 'penalty_early': 1.64, 'penalty_late': 1.07}
# Plane 43: {'appearance_time': 5100, 'earliest_landing_time': 5700, 'target_landing_time': 5943, 'latest_landing_time': 7500, 'penalty_early': 1.39, 'penalty_late': 1.02}
# Plane 44: {'appearance_time': 5101, 'earliest_landing_time': 5701, 'target_landing_time': 6210, 'latest_landing_time': 7501, 'penalty_early': 1.7, 'penalty_late': 1.35}
# Plane 45: {'appearance_time': 5204, 'earliest_landing_time': 5804, 'target_landing_time': 6143, 'latest_landing_time': 7604, 'penalty_early': 1.69, 'penalty_late': 1.32}
# Plane 46: {'appearance_time': 5249, 'earliest_landing_time': 5849, 'target_landing_time': 6157, 'latest_landing_time': 7649, 'penalty_early': 1.21, 'penalty_late': 1.31}
# Plane 47: {'appearance_time': 5277, 'earliest_landing_time': 5877, 'target_landing_time': 6212, 'latest_landing_time': 7677, 'penalty_early': 1.13, 'penalty_late': 1.23}
# Plane 48: {'appearance_time': 5400, 'earliest_landing_time': 6000, 'target_landing_time': 6109, 'latest_landing_time': 7800, 'penalty_early': 1.91, 'penalty_late': 1.07}
# Plane 49: {'appearance_time': 5591, 'earliest_landing_time': 6191, 'target_landing_time': 6321, 'latest_landing_time': 7991, 'penalty_early': 1.36, 'penalty_late': 1.18}
# Plane 50: {'appearance_time': 5886, 'earliest_landing_time': 6486, 'target_landing_time': 6753, 'latest_landing_time': 8286, 'penalty_early': 1.47, 'penalty_late': 1.29}
# Plane 51: {'appearance_time': 5913, 'earliest_landing_time': 6513, 'target_landing_time': 7089, 'latest_landing_time': 8313, 'penalty_early': 1.19, 'penalty_late': 1.59}
# Plane 52: {'appearance_time': 6022, 'earliest_landing_time': 6622, 'target_landing_time': 6937, 'latest_landing_time': 8422, 'penalty_early': 1.51, 'penalty_late': 1.21}
# Plane 53: {'appearance_time': 6180, 'earliest_landing_time': 6780, 'target_landing_time': 7041, 'latest_landing_time': 8580, 'penalty_early': 1.08, 'penalty_late': 1.66}
# Plane 54: {'appearance_time': 6293, 'earliest_landing_time': 6893, 'target_landing_time': 7157, 'latest_landing_time': 8693, 'penalty_early': 1.46, 'penalty_late': 1.88}
# Plane 55: {'appearance_time': 6356, 'earliest_landing_time': 6956, 'target_landing_time': 7206, 'latest_landing_time': 8756, 'penalty_early': 1.86, 'penalty_late': 1.65}
# Plane 56: {'appearance_time': 6522, 'earliest_landing_time': 7122, 'target_landing_time': 7614, 'latest_landing_time': 8922, 'penalty_early': 1.01, 'penalty_late': 1.49}
# Plane 57: {'appearance_time': 6537, 'earliest_landing_time': 7137, 'target_landing_time': 7269, 'latest_landing_time': 8937, 'penalty_early': 1.4, 'penalty_late': 1.94}
# Plane 58: {'appearance_time': 6556, 'earliest_landing_time': 7156, 'target_landing_time': 7446, 'latest_landing_time': 8956, 'penalty_early': 1.44, 'penalty_late': 1.32}
# Plane 59: {'appearance_time': 6569, 'earliest_landing_time': 7169, 'target_landing_time': 7348, 'latest_landing_time': 8969, 'penalty_early': 1.62, 'penalty_late': 1.94}
# Plane 60: {'appearance_time': 6576, 'earliest_landing_time': 7176, 'target_landing_time': 7290, 'latest_landing_time': 8976, 'penalty_early': 1.44, 'penalty_late': 1.34}
# Plane 61: {'appearance_time': 6618, 'earliest_landing_time': 7218, 'target_landing_time': 7607, 'latest_landing_time': 9018, 'penalty_early': 1.02, 'penalty_late': 1.54}
# Plane 62: {'appearance_time': 6719, 'earliest_landing_time': 7319, 'target_landing_time': 7452, 'latest_landing_time': 9119, 'penalty_early': 1.31, 'penalty_late': 1.91}
# Plane 63: {'appearance_time': 6825, 'earliest_landing_time': 7425, 'target_landing_time': 7844, 'latest_landing_time': 9225, 'penalty_early': 1.48, 'penalty_late': 1.53}
# Plane 64: {'appearance_time': 6934, 'earliest_landing_time': 7534, 'target_landing_time': 7706, 'latest_landing_time': 9334, 'penalty_early': 1.8, 'penalty_late': 1.29}
# Plane 65: {'appearance_time': 7301, 'earliest_landing_time': 7901, 'target_landing_time': 8243, 'latest_landing_time': 9701, 'penalty_early': 1.81, 'penalty_late': 1.43}
# Plane 66: {'appearance_time': 7357, 'earliest_landing_time': 7957, 'target_landing_time': 8351, 'latest_landing_time': 9757, 'penalty_early': 1.55, 'penalty_late': 1.26}
# Plane 67: {'appearance_time': 7423, 'earliest_landing_time': 8023, 'target_landing_time': 8155, 'latest_landing_time': 9823, 'penalty_early': 1.35, 'penalty_late': 1.07}
# Plane 68: {'appearance_time': 7536, 'earliest_landing_time': 8136, 'target_landing_time': 8202, 'latest_landing_time': 9936, 'penalty_early': 1.03, 'penalty_late': 1.09}
# Plane 69: {'appearance_time': 7608, 'earliest_landing_time': 8208, 'target_landing_time': 8766, 'latest_landing_time': 10008, 'penalty_early': 1.3, 'penalty_late': 1.04}
# Plane 70: {'appearance_time': 7705, 'earliest_landing_time': 8305, 'target_landing_time': 8651, 'latest_landing_time': 10105, 'penalty_early': 1.31, 'penalty_late': 1.39}
# Plane 71: {'appearance_time': 7708, 'earliest_landing_time': 8308, 'target_landing_time': 8849, 'latest_landing_time': 10108, 'penalty_early': 1.96, 'penalty_late': 1.94}
# Plane 72: {'appearance_time': 7713, 'earliest_landing_time': 8313, 'target_landing_time': 8645, 'latest_landing_time': 10113, 'penalty_early': 1.95, 'penalty_late': 1.4}
# Plane 73: {'appearance_time': 7975, 'earliest_landing_time': 8575, 'target_landing_time': 8881, 'latest_landing_time': 10375, 'penalty_early': 1.0, 'penalty_late': 1.37}
# Plane 74: {'appearance_time': 7977, 'earliest_landing_time': 8577, 'target_landing_time': 9022, 'latest_landing_time': 10377, 'penalty_early': 1.64, 'penalty_late': 1.9}
# Plane 75: {'appearance_time': 8053, 'earliest_landing_time': 8653, 'target_landing_time': 8989, 'latest_landing_time': 10453, 'penalty_early': 1.36, 'penalty_late': 1.79}
# Plane 76: {'appearance_time': 8178, 'earliest_landing_time': 8778, 'target_landing_time': 9144, 'latest_landing_time': 10578, 'penalty_early': 1.19, 'penalty_late': 1.76}
# Plane 77: {'appearance_time': 8330, 'earliest_landing_time': 8930, 'target_landing_time': 9430, 'latest_landing_time': 10730, 'penalty_early': 1.12, 'penalty_late': 1.05}
# Plane 78: {'appearance_time': 8556, 'earliest_landing_time': 9156, 'target_landing_time': 9638, 'latest_landing_time': 10956, 'penalty_early': 1.09, 'penalty_late': 1.23}
# Plane 79: {'appearance_time': 8675, 'earliest_landing_time': 9275, 'target_landing_time': 9865, 'latest_landing_time': 11075, 'penalty_early': 1.84, 'penalty_late': 1.79}
# Plane 80: {'appearance_time': 8748, 'earliest_landing_time': 9348, 'target_landing_time': 9799, 'latest_landing_time': 11148, 'penalty_early': 1.11, 'penalty_late': 1.86}
# Plane 81: {'appearance_time': 8832, 'earliest_landing_time': 9432, 'target_landing_time': 9894, 'latest_landing_time': 11232, 'penalty_early': 1.43, 'penalty_late': 1.23}
# Plane 82: {'appearance_time': 8833, 'earliest_landing_time': 9433, 'target_landing_time': 9699, 'latest_landing_time': 11233, 'penalty_early': 1.08, 'penalty_late': 1.24}
# Plane 83: {'appearance_time': 8997, 'earliest_landing_time': 9597, 'target_landing_time': 9790, 'latest_landing_time': 11397, 'penalty_early': 1.26, 'penalty_late': 1.26}
# Plane 84: {'appearance_time': 9115, 'earliest_landing_time': 9715, 'target_landing_time': 10314, 'latest_landing_time': 11515, 'penalty_early': 1.8, 'penalty_late': 1.37}
# Plane 85: {'appearance_time': 9191, 'earliest_landing_time': 9791, 'target_landing_time': 10149, 'latest_landing_time': 11591, 'penalty_early': 1.29, 'penalty_late': 1.71}
# Plane 86: {'appearance_time': 9281, 'earliest_landing_time': 9881, 'target_landing_time': 10126, 'latest_landing_time': 11681, 'penalty_early': 1.31, 'penalty_late': 1.52}
# Plane 87: {'appearance_time': 9658, 'earliest_landing_time': 10258, 'target_landing_time': 10360, 'latest_landing_time': 12058, 'penalty_early': 1.66, 'penalty_late': 1.16}
# Plane 88: {'appearance_time': 9764, 'earliest_landing_time': 10364, 'target_landing_time': 10791, 'latest_landing_time': 12164, 'penalty_early': 1.82, 'penalty_late': 1.72}
# Plane 89: {'appearance_time': 10031, 'earliest_landing_time': 10631, 'target_landing_time': 10949, 'latest_landing_time': 12431, 'penalty_early': 1.12, 'penalty_late': 1.92}
# Plane 90: {'appearance_time': 10279, 'earliest_landing_time': 10879, 'target_landing_time': 11427, 'latest_landing_time': 12679, 'penalty_early': 1.01, 'penalty_late': 1.3}
# Plane 91: {'appearance_time': 10524, 'earliest_landing_time': 11124, 'target_landing_time': 11692, 'latest_landing_time': 12924, 'penalty_early': 2.0, 'penalty_late': 1.64}
# Plane 92: {'appearance_time': 10564, 'earliest_landing_time': 11164, 'target_landing_time': 11644, 'latest_landing_time': 12964, 'penalty_early': 1.93, 'penalty_late': 1.47}
# Plane 93: {'appearance_time': 10612, 'earliest_landing_time': 11212, 'target_landing_time': 11334, 'latest_landing_time': 13012, 'penalty_early': 1.69, 'penalty_late': 1.21}
# Plane 94: {'appearance_time': 10693, 'earliest_landing_time': 11293, 'target_landing_time': 11547, 'latest_landing_time': 13093, 'penalty_early': 1.28, 'penalty_late': 1.32}
# Plane 95: {'appearance_time': 10755, 'earliest_landing_time': 11355, 'target_landing_time': 11626, 'latest_landing_time': 13155, 'penalty_early': 1.34, 'penalty_late': 1.14}
# Plane 96: {'appearance_time': 10834, 'earliest_landing_time': 11434, 'target_landing_time': 11616, 'latest_landing_time': 13234, 'penalty_early': 1.45, 'penalty_late': 1.74}
# Plane 97: {'appearance_time': 11151, 'earliest_landing_time': 11751, 'target_landing_time': 12032, 'latest_landing_time': 13551, 'penalty_early': 1.39, 'penalty_late': 1.14}
# Plane 98: {'appearance_time': 11678, 'earliest_landing_time': 12278, 'target_landing_time': 12419, 'latest_landing_time': 14078, 'penalty_early': 1.92, 'penalty_late': 1.08}
# Plane 99: {'appearance_time': 11694, 'earliest_landing_time': 12294, 'target_landing_time': 12713, 'latest_landing_time': 14094, 'penalty_early': 1.09, 'penalty_late': 1.14}
# Plane 100: {'appearance_time': 11733, 'earliest_landing_time': 12333, 'target_landing_time': 12750, 'latest_landing_time': 14133, 'penalty_early': 1.93, 'penalty_late': 1.13}
# Plane 101: {'appearance_time': 11996, 'earliest_landing_time': 12596, 'target_landing_time': 13069, 'latest_landing_time': 14396, 'penalty_early': 1.99, 'penalty_late': 1.73}
# Plane 102: {'appearance_time': 12004, 'earliest_landing_time': 12604, 'target_landing_time': 13053, 'latest_landing_time': 14404, 'penalty_early': 1.02, 'penalty_late': 1.68}
# Plane 103: {'appearance_time': 12168, 'earliest_landing_time': 12768, 'target_landing_time': 13128, 'latest_landing_time': 14568, 'penalty_early': 1.5, 'penalty_late': 1.61}
# Plane 104: {'appearance_time': 12211, 'earliest_landing_time': 12811, 'target_landing_time': 13062, 'latest_landing_time': 14611, 'penalty_early': 1.87, 'penalty_late': 1.24}
# Plane 105: {'appearance_time': 12375, 'earliest_landing_time': 12975, 'target_landing_time': 13147, 'latest_landing_time': 14775, 'penalty_early': 1.83, 'penalty_late': 1.26}
# Plane 106: {'appearance_time': 12523, 'earliest_landing_time': 13123, 'target_landing_time': 13244, 'latest_landing_time': 14923, 'penalty_early': 1.72, 'penalty_late': 1.16}
# Plane 107: {'appearance_time': 12562, 'earliest_landing_time': 13162, 'target_landing_time': 13675, 'latest_landing_time': 14962, 'penalty_early': 1.31, 'penalty_late': 1.78}
# Plane 108: {'appearance_time': 12722, 'earliest_landing_time': 13322, 'target_landing_time': 13493, 'latest_landing_time': 15122, 'penalty_early': 1.03, 'penalty_late': 1.04}
# Plane 109: {'appearance_time': 12901, 'earliest_landing_time': 13501, 'target_landing_time': 13920, 'latest_landing_time': 15301, 'penalty_early': 1.9, 'penalty_late': 1.58}
# Plane 110: {'appearance_time': 12995, 'earliest_landing_time': 13595, 'target_landing_time': 13799, 'latest_landing_time': 15395, 'penalty_early': 1.55, 'penalty_late': 1.15}
# Plane 111: {'appearance_time': 12999, 'earliest_landing_time': 13599, 'target_landing_time': 13875, 'latest_landing_time': 15399, 'penalty_early': 1.28, 'penalty_late': 1.9}
# Plane 112: {'appearance_time': 13010, 'earliest_landing_time': 13610, 'target_landing_time': 14091, 'latest_landing_time': 15410, 'penalty_early': 1.03, 'penalty_late': 1.03}
# Plane 113: {'appearance_time': 13066, 'earliest_landing_time': 13666, 'target_landing_time': 14254, 'latest_landing_time': 15466, 'penalty_early': 1.48, 'penalty_late': 1.3}
# Plane 114: {'appearance_time': 13118, 'earliest_landing_time': 13718, 'target_landing_time': 13802, 'latest_landing_time': 15518, 'penalty_early': 1.44, 'penalty_late': 1.25}
# Plane 115: {'appearance_time': 13129, 'earliest_landing_time': 13729, 'target_landing_time': 13803, 'latest_landing_time': 15529, 'penalty_early': 1.94, 'penalty_late': 1.85}
# Plane 116: {'appearance_time': 13252, 'earliest_landing_time': 13852, 'target_landing_time': 14055, 'latest_landing_time': 15652, 'penalty_early': 1.4, 'penalty_late': 1.79}
# Plane 117: {'appearance_time': 13280, 'earliest_landing_time': 13880, 'target_landing_time': 14127, 'latest_landing_time': 15680, 'penalty_early': 1.06, 'penalty_late': 1.34}
# Plane 118: {'appearance_time': 13392, 'earliest_landing_time': 13992, 'target_landing_time': 14060, 'latest_landing_time': 15792, 'penalty_early': 1.95, 'penalty_late': 1.78}
# Plane 119: {'appearance_time': 13520, 'earliest_landing_time': 14120, 'target_landing_time': 14495, 'latest_landing_time': 15920, 'penalty_early': 1.84, 'penalty_late': 1.64}
# Plane 120: {'appearance_time': 13600, 'earliest_landing_time': 14200, 'target_landing_time': 14416, 'latest_landing_time': 16000, 'penalty_early': 1.43, 'penalty_late': 1.59}
# Plane 121: {'appearance_time': 13612, 'earliest_landing_time': 14212, 'target_landing_time': 14803, 'latest_landing_time': 16012, 'penalty_early': 1.32, 'penalty_late': 1.37}
# Plane 122: {'appearance_time': 13963, 'earliest_landing_time': 14563, 'target_landing_time': 15113, 'latest_landing_time': 16363, 'penalty_early': 1.78, 'penalty_late': 1.78}
# Plane 123: {'appearance_time': 14014, 'earliest_landing_time': 14614, 'target_landing_time': 15023, 'latest_landing_time': 16414, 'penalty_early': 1.66, 'penalty_late': 1.3}
# Plane 124: {'appearance_time': 14050, 'earliest_landing_time': 14650, 'target_landing_time': 14840, 'latest_landing_time': 16450, 'penalty_early': 1.6, 'penalty_late': 1.77}
# Plane 125: {'appearance_time': 14062, 'earliest_landing_time': 14662, 'target_landing_time': 14933, 'latest_landing_time': 16462, 'penalty_early': 1.68, 'penalty_late': 1.78}
# Plane 126: {'appearance_time': 14100, 'earliest_landing_time': 14700, 'target_landing_time': 14861, 'latest_landing_time': 16500, 'penalty_early': 1.08, 'penalty_late': 1.76}
# Plane 127: {'appearance_time': 14324, 'earliest_landing_time': 14924, 'target_landing_time': 15022, 'latest_landing_time': 16724, 'penalty_early': 1.42, 'penalty_late': 1.55}
# Plane 128: {'appearance_time': 14328, 'earliest_landing_time': 14928, 'target_landing_time': 15508, 'latest_landing_time': 16728, 'penalty_early': 1.95, 'penalty_late': 1.63}
# Plane 129: {'appearance_time': 14440, 'earliest_landing_time': 15040, 'target_landing_time': 15411, 'latest_landing_time': 16840, 'penalty_early': 1.46, 'penalty_late': 1.18}
# Plane 130: {'appearance_time': 14447, 'earliest_landing_time': 15047, 'target_landing_time': 15321, 'latest_landing_time': 16847, 'penalty_early': 1.56, 'penalty_late': 1.93}
# Plane 131: {'appearance_time': 14466, 'earliest_landing_time': 15066, 'target_landing_time': 15522, 'latest_landing_time': 16866, 'penalty_early': 1.28, 'penalty_late': 1.84}
# Plane 132: {'appearance_time': 14535, 'earliest_landing_time': 15135, 'target_landing_time': 15263, 'latest_landing_time': 16935, 'penalty_early': 1.18, 'penalty_late': 1.82}
# Plane 133: {'appearance_time': 14975, 'earliest_landing_time': 15575, 'target_landing_time': 16004, 'latest_landing_time': 17375, 'penalty_early': 1.43, 'penalty_late': 1.04}
# Plane 134: {'appearance_time': 15164, 'earliest_landing_time': 15764, 'target_landing_time': 15965, 'latest_landing_time': 17564, 'penalty_early': 1.24, 'penalty_late': 1.56}
# Plane 135: {'appearance_time': 15169, 'earliest_landing_time': 15769, 'target_landing_time': 16245, 'latest_landing_time': 17569, 'penalty_early': 1.31, 'penalty_late': 1.09}
# Plane 136: {'appearance_time': 15368, 'earliest_landing_time': 15968, 'target_landing_time': 16094, 'latest_landing_time': 17768, 'penalty_early': 1.54, 'penalty_late': 1.26}
# Plane 137: {'appearance_time': 15452, 'earliest_landing_time': 16052, 'target_landing_time': 16563, 'latest_landing_time': 17852, 'penalty_early': 1.06, 'penalty_late': 1.75}
# Plane 138: {'appearance_time': 15510, 'earliest_landing_time': 16110, 'target_landing_time': 16534, 'latest_landing_time': 17910, 'penalty_early': 1.78, 'penalty_late': 1.58}
# Plane 139: {'appearance_time': 15832, 'earliest_landing_time': 16432, 'target_landing_time': 16580, 'latest_landing_time': 18232, 'penalty_early': 1.43, 'penalty_late': 1.6}
# Plane 140: {'appearance_time': 15979, 'earliest_landing_time': 16579, 'target_landing_time': 16889, 'latest_landing_time': 18379, 'penalty_early': 1.85, 'penalty_late': 1.36}
# Plane 141: {'appearance_time': 15991, 'earliest_landing_time': 16591, 'target_landing_time': 16772, 'latest_landing_time': 18391, 'penalty_early': 1.69, 'penalty_late': 1.28}
# Plane 142: {'appearance_time': 16023, 'earliest_landing_time': 16623, 'target_landing_time': 16959, 'latest_landing_time': 18423, 'penalty_early': 1.4, 'penalty_late': 1.34}
# Plane 143: {'appearance_time': 16251, 'earliest_landing_time': 16851, 'target_landing_time': 17000, 'latest_landing_time': 18651, 'penalty_early': 1.65, 'penalty_late': 1.31}
# Plane 144: {'appearance_time': 16328, 'earliest_landing_time': 16928, 'target_landing_time': 17309, 'latest_landing_time': 18728, 'penalty_early': 1.58, 'penalty_late': 1.99}
# Plane 145: {'appearance_time': 16393, 'earliest_landing_time': 16993, 'target_landing_time': 17086, 'latest_landing_time': 18793, 'penalty_early': 1.94, 'penalty_late': 1.08}
# Plane 146: {'appearance_time': 16582, 'earliest_landing_time': 17182, 'target_landing_time': 17685, 'latest_landing_time': 18982, 'penalty_early': 1.45, 'penalty_late': 1.33}
# Plane 147: {'appearance_time': 16626, 'earliest_landing_time': 17226, 'target_landing_time': 17584, 'latest_landing_time': 19026, 'penalty_early': 1.32, 'penalty_late': 1.48}
# Plane 148: {'appearance_time': 16636, 'earliest_landing_time': 17236, 'target_landing_time': 17374, 'latest_landing_time': 19036, 'penalty_early': 1.84, 'penalty_late': 1.14}
# Plane 149: {'appearance_time': 16655, 'earliest_landing_time': 17255, 'target_landing_time': 17784, 'latest_landing_time': 19055, 'penalty_early': 1.64, 'penalty_late': 1.72}
# Plane 150: {'appearance_time': 16772, 'earliest_landing_time': 17372, 'target_landing_time': 17566, 'latest_landing_time': 19172, 'penalty_early': 1.23, 'penalty_late': 1.76}
# Plane 151: {'appearance_time': 16853, 'earliest_landing_time': 17453, 'target_landing_time': 17868, 'latest_landing_time': 19253, 'penalty_early': 1.02, 'penalty_late': 1.96}
# Plane 152: {'appearance_time': 16883, 'earliest_landing_time': 17483, 'target_landing_time': 17681, 'latest_landing_time': 19283, 'penalty_early': 1.47, 'penalty_late': 2.0}
# Plane 153: {'appearance_time': 17227, 'earliest_landing_time': 17827, 'target_landing_time': 17920, 'latest_landing_time': 19627, 'penalty_early': 1.31, 'penalty_late': 1.22}
# Plane 154: {'appearance_time': 17464, 'earliest_landing_time': 18064, 'target_landing_time': 18204, 'latest_landing_time': 19864, 'penalty_early': 1.99, 'penalty_late': 1.88}
# Plane 155: {'appearance_time': 17785, 'earliest_landing_time': 18385, 'target_landing_time': 18774, 'latest_landing_time': 20185, 'penalty_early': 1.65, 'penalty_late': 1.27}
# Plane 156: {'appearance_time': 18185, 'earliest_landing_time': 18785, 'target_landing_time': 19235, 'latest_landing_time': 20585, 'penalty_early': 1.94, 'penalty_late': 1.64}
# Plane 157: {'appearance_time': 18215, 'earliest_landing_time': 18815, 'target_landing_time': 19392, 'latest_landing_time': 20615, 'penalty_early': 1.33, 'penalty_late': 1.49}
# Plane 158: {'appearance_time': 18362, 'earliest_landing_time': 18962, 'target_landing_time': 19480, 'latest_landing_time': 20762, 'penalty_early': 1.04, 'penalty_late': 1.9}
# Plane 159: {'appearance_time': 18439, 'earliest_landing_time': 19039, 'target_landing_time': 19318, 'latest_landing_time': 20839, 'penalty_early': 1.83, 'penalty_late': 1.65}
# Plane 160: {'appearance_time': 18492, 'earliest_landing_time': 19092, 'target_landing_time': 19478, 'latest_landing_time': 20892, 'penalty_early': 1.75, 'penalty_late': 1.43}
# Plane 161: {'appearance_time': 18633, 'earliest_landing_time': 19233, 'target_landing_time': 19488, 'latest_landing_time': 21033, 'penalty_early': 1.33, 'penalty_late': 1.95}
# Plane 162: {'appearance_time': 18672, 'earliest_landing_time': 19272, 'target_landing_time': 19718, 'latest_landing_time': 21072, 'penalty_early': 1.15, 'penalty_late': 1.84}
# Plane 163: {'appearance_time': 18776, 'earliest_landing_time': 19376, 'target_landing_time': 19776, 'latest_landing_time': 21176, 'penalty_early': 1.39, 'penalty_late': 1.28}
# Plane 164: {'appearance_time': 18824, 'earliest_landing_time': 19424, 'target_landing_time': 19535, 'latest_landing_time': 21224, 'penalty_early': 1.7, 'penalty_late': 1.5}
# Plane 165: {'appearance_time': 18908, 'earliest_landing_time': 19508, 'target_landing_time': 20095, 'latest_landing_time': 21308, 'penalty_early': 1.99, 'penalty_late': 1.09}
# Plane 166: {'appearance_time': 19195, 'earliest_landing_time': 19795, 'target_landing_time': 20184, 'latest_landing_time': 21595, 'penalty_early': 1.25, 'penalty_late': 1.44}
# Plane 167: {'appearance_time': 19461, 'earliest_landing_time': 20061, 'target_landing_time': 20507, 'latest_landing_time': 21861, 'penalty_early': 1.3, 'penalty_late': 1.73}
# Plane 168: {'appearance_time': 19543, 'earliest_landing_time': 20143, 'target_landing_time': 20426, 'latest_landing_time': 21943, 'penalty_early': 1.02, 'penalty_late': 1.93}
# Plane 169: {'appearance_time': 20047, 'earliest_landing_time': 20647, 'target_landing_time': 20855, 'latest_landing_time': 22447, 'penalty_early': 1.62, 'penalty_late': 1.89}
# Plane 170: {'appearance_time': 20503, 'earliest_landing_time': 21103, 'target_landing_time': 21208, 'latest_landing_time': 22903, 'penalty_early': 1.2, 'penalty_late': 1.37}
# Plane 171: {'appearance_time': 20582, 'earliest_landing_time': 21182, 'target_landing_time': 21654, 'latest_landing_time': 22982, 'penalty_early': 1.1, 'penalty_late': 1.84}
# Plane 172: {'appearance_time': 20815, 'earliest_landing_time': 21415, 'target_landing_time': 21753, 'latest_landing_time': 23215, 'penalty_early': 1.5, 'penalty_late': 1.27}
# Plane 173: {'appearance_time': 20891, 'earliest_landing_time': 21491, 'target_landing_time': 22077, 'latest_landing_time': 23291, 'penalty_early': 1.88, 'penalty_late': 1.91}
# Plane 174: {'appearance_time': 20978, 'earliest_landing_time': 21578, 'target_landing_time': 21851, 'latest_landing_time': 23378, 'penalty_early': 1.62, 'penalty_late': 1.72}
# Plane 175: {'appearance_time': 21141, 'earliest_landing_time': 21741, 'target_landing_time': 22229, 'latest_landing_time': 23541, 'penalty_early': 1.56, 'penalty_late': 1.45}
# Plane 176: {'appearance_time': 21518, 'earliest_landing_time': 22118, 'target_landing_time': 22517, 'latest_landing_time': 23918, 'penalty_early': 1.7, 'penalty_late': 1.88}
# Plane 177: {'appearance_time': 21545, 'earliest_landing_time': 22145, 'target_landing_time': 22666, 'latest_landing_time': 23945, 'penalty_early': 1.92, 'penalty_late': 1.66}
# Plane 178: {'appearance_time': 21615, 'earliest_landing_time': 22215, 'target_landing_time': 22626, 'latest_landing_time': 24015, 'penalty_early': 1.57, 'penalty_late': 1.37}
# Plane 179: {'appearance_time': 21765, 'earliest_landing_time': 22365, 'target_landing_time': 22948, 'latest_landing_time': 24165, 'penalty_early': 1.69, 'penalty_late': 1.25}
# Plane 180: {'appearance_time': 21985, 'earliest_landing_time': 22585, 'target_landing_time': 23044, 'latest_landing_time': 24385, 'penalty_early': 1.4, 'penalty_late': 1.3}
# Plane 181: {'appearance_time': 22181, 'earliest_landing_time': 22781, 'target_landing_time': 23212, 'latest_landing_time': 24581, 'penalty_early': 1.34, 'penalty_late': 1.97}
# Plane 182: {'appearance_time': 22321, 'earliest_landing_time': 22921, 'target_landing_time': 23241, 'latest_landing_time': 24721, 'penalty_early': 1.71, 'penalty_late': 1.5}
# Plane 183: {'appearance_time': 22328, 'earliest_landing_time': 22928, 'target_landing_time': 23399, 'latest_landing_time': 24728, 'penalty_early': 1.01, 'penalty_late': 1.2}
# Plane 184: {'appearance_time': 22572, 'earliest_landing_time': 23172, 'target_landing_time': 23307, 'latest_landing_time': 24972, 'penalty_early': 1.33, 'penalty_late': 1.38}
# Plane 185: {'appearance_time': 22724, 'earliest_landing_time': 23324, 'target_landing_time': 23511, 'latest_landing_time': 25124, 'penalty_early': 1.51, 'penalty_late': 1.42}
# Plane 186: {'appearance_time': 22788, 'earliest_landing_time': 23388, 'target_landing_time': 23899, 'latest_landing_time': 25188, 'penalty_early': 1.33, 'penalty_late': 1.91}
# Plane 187: {'appearance_time': 22812, 'earliest_landing_time': 23412, 'target_landing_time': 24007, 'latest_landing_time': 25212, 'penalty_early': 1.95, 'penalty_late': 1.54}
# Plane 188: {'appearance_time': 22861, 'earliest_landing_time': 23461, 'target_landing_time': 23828, 'latest_landing_time': 25261, 'penalty_early': 1.23, 'penalty_late': 1.34}
# Plane 189: {'appearance_time': 23020, 'earliest_landing_time': 23620, 'target_landing_time': 23942, 'latest_landing_time': 25420, 'penalty_early': 1.27, 'penalty_late': 1.01}
# Plane 190: {'appearance_time': 23080, 'earliest_landing_time': 23680, 'target_landing_time': 24014, 'latest_landing_time': 25480, 'penalty_early': 1.13, 'penalty_late': 1.07}
# Plane 191: {'appearance_time': 23099, 'earliest_landing_time': 23699, 'target_landing_time': 23969, 'latest_landing_time': 25499, 'penalty_early': 1.7, 'penalty_late': 1.74}
# Plane 192: {'appearance_time': 23264, 'earliest_landing_time': 23864, 'target_landing_time': 24087, 'latest_landing_time': 25664, 'penalty_early': 1.9, 'penalty_late': 1.25}
# Plane 193: {'appearance_time': 23284, 'earliest_landing_time': 23884, 'target_landing_time': 24001, 'latest_landing_time': 25684, 'penalty_early': 1.09, 'penalty_late': 1.1}
# Plane 194: {'appearance_time': 23446, 'earliest_landing_time': 24046, 'target_landing_time': 24269, 'latest_landing_time': 25846, 'penalty_early': 1.61, 'penalty_late': 1.5}
# Plane 195: {'appearance_time': 23577, 'earliest_landing_time': 24177, 'target_landing_time': 24582, 'latest_landing_time': 25977, 'penalty_early': 1.62, 'penalty_late': 1.14}
# Plane 196: {'appearance_time': 23613, 'earliest_landing_time': 24213, 'target_landing_time': 24594, 'latest_landing_time': 26013, 'penalty_early': 1.77, 'penalty_late': 1.02}
# Plane 197: {'appearance_time': 23647, 'earliest_landing_time': 24247, 'target_landing_time': 24812, 'latest_landing_time': 26047, 'penalty_early': 1.79, 'penalty_late': 1.75}
# Plane 198: {'appearance_time': 24043, 'earliest_landing_time': 24643, 'target_landing_time': 25065, 'latest_landing_time': 26443, 'penalty_early': 1.64, 'penalty_late': 1.36}
# Plane 199: {'appearance_time': 24053, 'earliest_landing_time': 24653, 'target_landing_time': 24969, 'latest_landing_time': 26453, 'penalty_early': 1.97, 'penalty_late': 1.19}
# Plane 200: {'appearance_time': 24146, 'earliest_landing_time': 24746, 'target_landing_time': 25107, 'latest_landing_time': 26546, 'penalty_early': 1.36, 'penalty_late': 1.53}
# Plane 201: {'appearance_time': 24307, 'earliest_landing_time': 24907, 'target_landing_time': 25156, 'latest_landing_time': 26707, 'penalty_early': 1.74, 'penalty_late': 1.31}
# Plane 202: {'appearance_time': 24428, 'earliest_landing_time': 25028, 'target_landing_time': 25242, 'latest_landing_time': 26828, 'penalty_early': 1.17, 'penalty_late': 1.2}
# Plane 203: {'appearance_time': 24650, 'earliest_landing_time': 25250, 'target_landing_time': 25384, 'latest_landing_time': 27050, 'penalty_early': 1.98, 'penalty_late': 1.94}
# Plane 204: {'appearance_time': 24652, 'earliest_landing_time': 25252, 'target_landing_time': 25438, 'latest_landing_time': 27052, 'penalty_early': 1.03, 'penalty_late': 1.38}
# Plane 205: {'appearance_time': 24894, 'earliest_landing_time': 25494, 'target_landing_time': 25803, 'latest_landing_time': 27294, 'penalty_early': 1.6, 'penalty_late': 1.67}
# Plane 206: {'appearance_time': 25176, 'earliest_landing_time': 25776, 'target_landing_time': 25866, 'latest_landing_time': 27576, 'penalty_early': 1.99, 'penalty_late': 1.18}
# Plane 207: {'appearance_time': 25217, 'earliest_landing_time': 25817, 'target_landing_time': 26210, 'latest_landing_time': 27617, 'penalty_early': 1.17, 'penalty_late': 1.3}
# Plane 208: {'appearance_time': 25295, 'earliest_landing_time': 25895, 'target_landing_time': 25991, 'latest_landing_time': 27695, 'penalty_early': 1.96, 'penalty_late': 1.32}
# Plane 209: {'appearance_time': 25340, 'earliest_landing_time': 25940, 'target_landing_time': 26460, 'latest_landing_time': 27740, 'penalty_early': 1.82, 'penalty_late': 1.16}
# Plane 210: {'appearance_time': 25362, 'earliest_landing_time': 25962, 'target_landing_time': 26329, 'latest_landing_time': 27762, 'penalty_early': 1.24, 'penalty_late': 1.15}
# Plane 211: {'appearance_time': 25480, 'earliest_landing_time': 26080, 'target_landing_time': 26183, 'latest_landing_time': 27880, 'penalty_early': 1.26, 'penalty_late': 1.16}
# Plane 212: {'appearance_time': 25482, 'earliest_landing_time': 26082, 'target_landing_time': 26426, 'latest_landing_time': 27882, 'penalty_early': 1.59, 'penalty_late': 1.53}
# Plane 213: {'appearance_time': 25499, 'earliest_landing_time': 26099, 'target_landing_time': 26498, 'latest_landing_time': 27899, 'penalty_early': 1.76, 'penalty_late': 1.77}
# Plane 214: {'appearance_time': 25518, 'earliest_landing_time': 26118, 'target_landing_time': 26486, 'latest_landing_time': 27918, 'penalty_early': 1.94, 'penalty_late': 1.19}
# Plane 215: {'appearance_time': 25619, 'earliest_landing_time': 26219, 'target_landing_time': 26300, 'latest_landing_time': 28019, 'penalty_early': 1.43, 'penalty_late': 1.68}
# Plane 216: {'appearance_time': 25786, 'earliest_landing_time': 26386, 'target_landing_time': 26769, 'latest_landing_time': 28186, 'penalty_early': 1.58, 'penalty_late': 1.73}
# Plane 217: {'appearance_time': 25826, 'earliest_landing_time': 26426, 'target_landing_time': 26713, 'latest_landing_time': 28226, 'penalty_early': 1.43, 'penalty_late': 1.55}
# Plane 218: {'appearance_time': 25890, 'earliest_landing_time': 26490, 'target_landing_time': 26894, 'latest_landing_time': 28290, 'penalty_early': 1.5, 'penalty_late': 1.96}
# Plane 219: {'appearance_time': 26108, 'earliest_landing_time': 26708, 'target_landing_time': 26909, 'latest_landing_time': 28508, 'penalty_early': 1.53, 'penalty_late': 1.79}
# Plane 220: {'appearance_time': 26178, 'earliest_landing_time': 26778, 'target_landing_time': 27174, 'latest_landing_time': 28578, 'penalty_early': 1.84, 'penalty_late': 1.02}
# Plane 221: {'appearance_time': 26254, 'earliest_landing_time': 26854, 'target_landing_time': 27208, 'latest_landing_time': 28654, 'penalty_early': 1.16, 'penalty_late': 1.78}
# Plane 222: {'appearance_time': 26353, 'earliest_landing_time': 26953, 'target_landing_time': 27236, 'latest_landing_time': 28753, 'penalty_early': 1.07, 'penalty_late': 1.86}
# Plane 223: {'appearance_time': 26456, 'earliest_landing_time': 27056, 'target_landing_time': 27501, 'latest_landing_time': 28856, 'penalty_early': 1.76, 'penalty_late': 1.26}
# Plane 224: {'appearance_time': 26657, 'earliest_landing_time': 27257, 'target_landing_time': 27621, 'latest_landing_time': 29057, 'penalty_early': 1.93, 'penalty_late': 1.2}
# Plane 225: {'appearance_time': 26663, 'earliest_landing_time': 27263, 'target_landing_time': 27669, 'latest_landing_time': 29063, 'penalty_early': 1.87, 'penalty_late': 1.19}
# Plane 226: {'appearance_time': 26743, 'earliest_landing_time': 27343, 'target_landing_time': 27692, 'latest_landing_time': 29143, 'penalty_early': 1.96, 'penalty_late': 1.45}
# Plane 227: {'appearance_time': 26806, 'earliest_landing_time': 27406, 'target_landing_time': 27684, 'latest_landing_time': 29206, 'penalty_early': 1.84, 'penalty_late': 1.16}
# Plane 228: {'appearance_time': 26893, 'earliest_landing_time': 27493, 'target_landing_time': 27622, 'latest_landing_time': 29293, 'penalty_early': 1.97, 'penalty_late': 1.77}
# Plane 229: {'appearance_time': 26923, 'earliest_landing_time': 27523, 'target_landing_time': 27967, 'latest_landing_time': 29323, 'penalty_early': 1.56, 'penalty_late': 1.9}
# Plane 230: {'appearance_time': 26966, 'earliest_landing_time': 27566, 'target_landing_time': 28081, 'latest_landing_time': 29366, 'penalty_early': 1.92, 'penalty_late': 1.02}
# Plane 231: {'appearance_time': 27148, 'earliest_landing_time': 27748, 'target_landing_time': 28148, 'latest_landing_time': 29548, 'penalty_early': 1.29, 'penalty_late': 1.23}
# Plane 232: {'appearance_time': 27164, 'earliest_landing_time': 27764, 'target_landing_time': 28049, 'latest_landing_time': 29564, 'penalty_early': 1.85, 'penalty_late': 1.27}
# Plane 233: {'appearance_time': 27191, 'earliest_landing_time': 27791, 'target_landing_time': 28152, 'latest_landing_time': 29591, 'penalty_early': 1.9, 'penalty_late': 1.25}
# Plane 234: {'appearance_time': 27232, 'earliest_landing_time': 27832, 'target_landing_time': 28174, 'latest_landing_time': 29632, 'penalty_early': 1.4, 'penalty_late': 1.05}
# Plane 235: {'appearance_time': 27316, 'earliest_landing_time': 27916, 'target_landing_time': 28313, 'latest_landing_time': 29716, 'penalty_early': 1.46, 'penalty_late': 1.31}
# Plane 236: {'appearance_time': 27522, 'earliest_landing_time': 28122, 'target_landing_time': 28305, 'latest_landing_time': 29922, 'penalty_early': 1.97, 'penalty_late': 1.99}
# Plane 237: {'appearance_time': 27618, 'earliest_landing_time': 28218, 'target_landing_time': 28779, 'latest_landing_time': 30018, 'penalty_early': 1.54, 'penalty_late': 1.97}
# Plane 238: {'appearance_time': 27668, 'earliest_landing_time': 28268, 'target_landing_time': 28597, 'latest_landing_time': 30068, 'penalty_early': 1.3, 'penalty_late': 1.58}
# Plane 239: {'appearance_time': 27680, 'earliest_landing_time': 28280, 'target_landing_time': 28780, 'latest_landing_time': 30080, 'penalty_early': 1.02, 'penalty_late': 1.98}
# Plane 240: {'appearance_time': 27711, 'earliest_landing_time': 28311, 'target_landing_time': 28668, 'latest_landing_time': 30111, 'penalty_early': 1.75, 'penalty_late': 1.3}
# Plane 241: {'appearance_time': 27839, 'earliest_landing_time': 28439, 'target_landing_time': 28634, 'latest_landing_time': 30239, 'penalty_early': 1.52, 'penalty_late': 1.79}
# Plane 242: {'appearance_time': 27883, 'earliest_landing_time': 28483, 'target_landing_time': 28974, 'latest_landing_time': 30283, 'penalty_early': 1.18, 'penalty_late': 1.26}
# Plane 243: {'appearance_time': 27986, 'earliest_landing_time': 28586, 'target_landing_time': 28657, 'latest_landing_time': 30386, 'penalty_early': 1.22, 'penalty_late': 1.29}
# Plane 244: {'appearance_time': 28317, 'earliest_landing_time': 28917, 'target_landing_time': 29442, 'latest_landing_time': 30717, 'penalty_early': 1.1, 'penalty_late': 1.37}
# Plane 245: {'appearance_time': 28367, 'earliest_landing_time': 28967, 'target_landing_time': 29363, 'latest_landing_time': 30767, 'penalty_early': 1.56, 'penalty_late': 1.12}
# Plane 246: {'appearance_time': 28409, 'earliest_landing_time': 29009, 'target_landing_time': 29078, 'latest_landing_time': 30809, 'penalty_early': 1.52, 'penalty_late': 1.65}
# Plane 247: {'appearance_time': 28451, 'earliest_landing_time': 29051, 'target_landing_time': 29242, 'latest_landing_time': 30851, 'penalty_early': 1.95, 'penalty_late': 1.29}
# Plane 248: {'appearance_time': 28561, 'earliest_landing_time': 29161, 'target_landing_time': 29542, 'latest_landing_time': 30961, 'penalty_early': 1.66, 'penalty_late': 1.3}
# Plane 249: {'appearance_time': 28721, 'earliest_landing_time': 29321, 'target_landing_time': 29860, 'latest_landing_time': 31121, 'penalty_early': 1.21, 'penalty_late': 1.41}
# Plane 250: {'appearance_time': 29018, 'earliest_landing_time': 29618, 'target_landing_time': 29930, 'latest_landing_time': 31418, 'penalty_early': 1.96, 'penalty_late': 1.39}
# Plane 251: {'appearance_time': 29140, 'earliest_landing_time': 29740, 'target_landing_time': 30059, 'latest_landing_time': 31540, 'penalty_early': 1.78, 'penalty_late': 1.9}
# Plane 252: {'appearance_time': 29158, 'earliest_landing_time': 29758, 'target_landing_time': 30331, 'latest_landing_time': 31558, 'penalty_early': 1.67, 'penalty_late': 1.41}
# Plane 253: {'appearance_time': 29197, 'earliest_landing_time': 29797, 'target_landing_time': 30350, 'latest_landing_time': 31597, 'penalty_early': 1.25, 'penalty_late': 1.87}
# Plane 254: {'appearance_time': 29258, 'earliest_landing_time': 29858, 'target_landing_time': 30301, 'latest_landing_time': 31658, 'penalty_early': 1.85, 'penalty_late': 1.66}
# Plane 255: {'appearance_time': 29286, 'earliest_landing_time': 29886, 'target_landing_time': 30125, 'latest_landing_time': 31686, 'penalty_early': 1.03, 'penalty_late': 1.76}
# Plane 256: {'appearance_time': 29334, 'earliest_landing_time': 29934, 'target_landing_time': 30417, 'latest_landing_time': 31734, 'penalty_early': 1.52, 'penalty_late': 1.09}
# Plane 257: {'appearance_time': 29351, 'earliest_landing_time': 29951, 'target_landing_time': 30496, 'latest_landing_time': 31751, 'penalty_early': 1.96, 'penalty_late': 1.52}
# Plane 258: {'appearance_time': 29445, 'earliest_landing_time': 30045, 'target_landing_time': 30201, 'latest_landing_time': 31845, 'penalty_early': 1.18, 'penalty_late': 1.45}
# Plane 259: {'appearance_time': 29823, 'earliest_landing_time': 30423, 'target_landing_time': 30721, 'latest_landing_time': 32223, 'penalty_early': 1.72, 'penalty_late': 1.38}
# Plane 260: {'appearance_time': 29865, 'earliest_landing_time': 30465, 'target_landing_time': 30862, 'latest_landing_time': 32265, 'penalty_early': 1.71, 'penalty_late': 1.56}
# Plane 261: {'appearance_time': 29908, 'earliest_landing_time': 30508, 'target_landing_time': 30608, 'latest_landing_time': 32308, 'penalty_early': 1.08, 'penalty_late': 1.46}
# Plane 262: {'appearance_time': 30228, 'earliest_landing_time': 30828, 'target_landing_time': 31213, 'latest_landing_time': 32628, 'penalty_early': 1.8, 'penalty_late': 1.49}
# Plane 263: {'appearance_time': 30246, 'earliest_landing_time': 30846, 'target_landing_time': 31385, 'latest_landing_time': 32646, 'penalty_early': 1.26, 'penalty_late': 1.08}
# Plane 264: {'appearance_time': 30247, 'earliest_landing_time': 30847, 'target_landing_time': 31212, 'latest_landing_time': 32647, 'penalty_early': 1.18, 'penalty_late': 1.4}
# Plane 265: {'appearance_time': 30350, 'earliest_landing_time': 30950, 'target_landing_time': 31151, 'latest_landing_time': 32750, 'penalty_early': 1.01, 'penalty_late': 1.56}
# Plane 266: {'appearance_time': 30371, 'earliest_landing_time': 30971, 'target_landing_time': 31191, 'latest_landing_time': 32771, 'penalty_early': 1.4, 'penalty_late': 1.48}
# Plane 267: {'appearance_time': 30575, 'earliest_landing_time': 31175, 'target_landing_time': 31342, 'latest_landing_time': 32975, 'penalty_early': 1.3, 'penalty_late': 1.72}
# Plane 268: {'appearance_time': 30615, 'earliest_landing_time': 31215, 'target_landing_time': 31624, 'latest_landing_time': 33015, 'penalty_early': 1.71, 'penalty_late': 1.85}
# Plane 269: {'appearance_time': 30739, 'earliest_landing_time': 31339, 'target_landing_time': 31604, 'latest_landing_time': 33139, 'penalty_early': 1.35, 'penalty_late': 1.85}
# Plane 270: {'appearance_time': 30760, 'earliest_landing_time': 31360, 'target_landing_time': 31595, 'latest_landing_time': 33160, 'penalty_early': 1.49, 'penalty_late': 1.72}
# Plane 271: {'appearance_time': 30773, 'earliest_landing_time': 31373, 'target_landing_time': 31770, 'latest_landing_time': 33173, 'penalty_early': 1.57, 'penalty_late': 1.52}
# Plane 272: {'appearance_time': 31023, 'earliest_landing_time': 31623, 'target_landing_time': 31796, 'latest_landing_time': 33423, 'penalty_early': 1.14, 'penalty_late': 1.89}
# Plane 273: {'appearance_time': 31142, 'earliest_landing_time': 31742, 'target_landing_time': 32000, 'latest_landing_time': 33542, 'penalty_early': 1.9, 'penalty_late': 1.97}
# Plane 274: {'appearance_time': 31218, 'earliest_landing_time': 31818, 'target_landing_time': 32267, 'latest_landing_time': 33618, 'penalty_early': 1.91, 'penalty_late': 1.14}
# Plane 275: {'appearance_time': 31257, 'earliest_landing_time': 31857, 'target_landing_time': 32389, 'latest_landing_time': 33657, 'penalty_early': 1.39, 'penalty_late': 1.8}
# Plane 276: {'appearance_time': 31366, 'earliest_landing_time': 31966, 'target_landing_time': 32463, 'latest_landing_time': 33766, 'penalty_early': 1.23, 'penalty_late': 1.63}
# ...
# After plane 494: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 495: [90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 90, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 90, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 68, 90, 68, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 90, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 90, 68, 90, 90, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 68, 68, 68, 90, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 90, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 90, 68, 90, 68, 68, 90, 90, 90, 90, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 90, 90, 90, 90, 68, 90, 68, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 90, 90, 68, 90, 68]
# After plane 496: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 497: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 498: [90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 90, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 90, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 68, 90, 68, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 90, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 90, 68, 90, 90, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 68, 68, 68, 90, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 90, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 90, 68, 90, 68, 68, 90, 90, 90, 90, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 90, 90, 90, 90, 68, 90, 68, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 90, 90, 68, 90, 68]
# After plane 499: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 500: [90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 90, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 90, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 68, 90, 68, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 90, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 90, 68, 90, 90, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 68, 90, 90, 68, 68, 68, 90, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 90, 90, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 90, 68, 90, 68, 68, 90, 90, 90, 90, 68, 68, 68, 68, 90, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 90, 90, 90, 90, 68, 90, 68, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 68, 90, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 90, 90, 68, 90, 68]

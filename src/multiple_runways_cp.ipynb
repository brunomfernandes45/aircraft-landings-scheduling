# %% [markdown]
# ## **Multiple-Runway Constraint Programming Model**
#
# <h4 style="color:#0033a0">Parameters</h4>

# %% [markdown]
# \begin{aligned}
# p
# & \quad \text{Number of aircraft (planes)}, \\[6pt]
# r
# & \quad \text{Number of runways}, \\[6pt]
# E_i
# & \quad \text{Earliest landing time for aircraft } i, \\[6pt]
# T_i
# & \quad \text{Target (preferred) landing time for aircraft } i, \\[6pt]
# L_i
# & \quad \text{Latest landing time for aircraft } i, \\[6pt]
# cost_e^i
# & \quad \text{Penalty cost per unit time if } t_i < T_i \ (\text{earliness cost}), \\[6pt]
# cost_l^i
# & \quad \text{Penalty cost per unit time if } t_i > T_i \ (\text{lateness cost}), \\[6pt]
# sep_{i,j}
# & \quad \text{Separation time required if aircraft } i \text{ lands immediately before } j
# \text{ (only if on the same runway)}.
# \end{aligned}

# %% [markdown]
# <br/> <h4 style="color:#0033a0">Decision Variables</h4>

# %% [markdown]
# \begin{aligned}
# position_i
# & \quad \text{Position of aircraft } i \text{ in the landing sequence}, \\[6pt]
# landing\_time_i
# & \quad \text{Landing time of aircraft } i, \\[6pt]
# earliness_i
# & \quad \text{Earliness of aircraft } i \text{ (if } t_i < T_i \text{)}, \\[6pt]
# lateness_i
# & \quad \text{Lateness of aircraft } i \text{ (if } t_i > T_i \text{)}, \\[6pt]
# runway_i
# & \quad \text{Runway assigned to aircraft } i.
# \end{aligned}

# %% [markdown]
# <br/> <h4 style="color:#0033a0">Objective Function and Constraints</h4>

# %% [markdown]
# \begin{aligned}
# \text{Constraints:} \\[6pt]
# & E_i \leq landing\_time_i \leq L_i \quad \forall i, \\[6pt]
# & earliness_i \geq T_i - landing\_time_i \quad \forall i, \\[6pt]
# & earliness_i \geq 0 \quad \forall i, \\[6pt]
# & lateness_i \geq landing\_time_i - T_i \quad \forall i, \\[6pt]
# & lateness_i \geq 0 \quad \forall i, \\[6pt]
# & \text{If } runway_i = runway_j \text{ and } position_i < position_j, \text{ then } landing\_time_j \geq landing\_time_i + sep_{i,j} \quad \forall i, j.
# \end{aligned}
#
# \begin{aligned}
# \text{Objective Function:} \\[6pt]
# & \text{Minimize } \sum_{i=1}^{p} (cost_e^i \cdot earliness_i + cost_l^i \cdot lateness_i).
# \end{aligned}

# %%
def read_data_from_file(filename):
    """
    Reads data from a file with the specified format for an air traffic scheduling problem.

    Args:
        filename (str): The path to the data file.

    Returns:
        tuple: A tuple containing the parsed data:
            - num_planes (int): The number of planes.
            - freeze_time (int): The freeze time.
            - planes_data (list): A list of dictionaries, where each dictionary contains
              the data for a plane.
            - separation_times (list of lists): A 2D list of separation times.
    """
    try:
        with open(filename, "r") as f:
            # Read the first line: number of planes and freeze time
            first_line = f.readline().strip().split()
            num_planes = int(first_line[0])
            freeze_time = int(first_line[1])

            planes_data = []
            separation_times = []
            
            for _ in range(num_planes):
                line = f.readline().strip().split()
                appearance_time = int(line[0])
                earliest_landing_time = int(line[1])
                target_landing_time = int(line[2])
                latest_landing_time = int(line[3])
                penalty_early = float(line[4])
                penalty_late = float(line[5])
                planes_data.append(
                    {
                        "appearance_time": appearance_time,
                        "earliest_landing_time": earliest_landing_time,
                        "target_landing_time": target_landing_time,
                        "latest_landing_time": latest_landing_time,
                        "penalty_early": penalty_early,
                        "penalty_late": penalty_late,
                    }
                )
                
                separation_row = []
                while len(separation_row) < num_planes:
                    line = f.readline().strip().split()
                    separation_row.extend([int(x) for x in line])

                separation_times.append(separation_row)

        return num_planes, freeze_time, planes_data, separation_times

    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None, None, None, None
    except ValueError:
        print(f"Error: Error reading data in file '{filename}'.")
        return None, None, None, None

# %%
filename = "data/airland1.txt"

num_planes, freeze_time, planes_data, separation_times = read_data_from_file(filename)

if num_planes is not None:
    print("Number of planes:", num_planes)
    print("Freeze time:", freeze_time)
    print("\nPlane data:")
    for i, plane in enumerate(planes_data):
        print(f"Plane {i+1}: {plane}")
    print("\nSeparation times:")
    for i, row in enumerate(separation_times):
        print(f"After plane {i+1}: {row}")
# Out:
# Number of planes: 100
# Freeze time: 720
#
# Plane data:
# Plane 1: {'appearance_time': 1, 'earliest_landing_time': 601, 'target_landing_time': 908, 'latest_landing_time': 2401, 'penalty_early': 1.45, 'penalty_late': 1.1}
# Plane 2: {'appearance_time': 125, 'earliest_landing_time': 725, 'target_landing_time': 1027, 'latest_landing_time': 2525, 'penalty_early': 1.82, 'penalty_late': 1.56}
# Plane 3: {'appearance_time': 328, 'earliest_landing_time': 928, 'target_landing_time': 1378, 'latest_landing_time': 2728, 'penalty_early': 1.4, 'penalty_late': 1.85}
# Plane 4: {'appearance_time': 374, 'earliest_landing_time': 974, 'target_landing_time': 1502, 'latest_landing_time': 2774, 'penalty_early': 1.76, 'penalty_late': 1.27}
# Plane 5: {'appearance_time': 456, 'earliest_landing_time': 1056, 'target_landing_time': 1618, 'latest_landing_time': 2856, 'penalty_early': 1.67, 'penalty_late': 1.55}
# Plane 6: {'appearance_time': 519, 'earliest_landing_time': 1119, 'target_landing_time': 1235, 'latest_landing_time': 2919, 'penalty_early': 1.39, 'penalty_late': 1.63}
# Plane 7: {'appearance_time': 548, 'earliest_landing_time': 1148, 'target_landing_time': 1520, 'latest_landing_time': 2948, 'penalty_early': 1.94, 'penalty_late': 1.22}
# Plane 8: {'appearance_time': 595, 'earliest_landing_time': 1195, 'target_landing_time': 1401, 'latest_landing_time': 2995, 'penalty_early': 1.59, 'penalty_late': 1.82}
# Plane 9: {'appearance_time': 601, 'earliest_landing_time': 1201, 'target_landing_time': 1584, 'latest_landing_time': 3001, 'penalty_early': 1.02, 'penalty_late': 1.33}
# Plane 10: {'appearance_time': 618, 'earliest_landing_time': 1218, 'target_landing_time': 1343, 'latest_landing_time': 3018, 'penalty_early': 1.59, 'penalty_late': 1.88}
# Plane 11: {'appearance_time': 624, 'earliest_landing_time': 1224, 'target_landing_time': 1787, 'latest_landing_time': 3024, 'penalty_early': 1.62, 'penalty_late': 1.15}
# Plane 12: {'appearance_time': 688, 'earliest_landing_time': 1288, 'target_landing_time': 1700, 'latest_landing_time': 3088, 'penalty_early': 1.13, 'penalty_late': 1.76}
# Plane 13: {'appearance_time': 1013, 'earliest_landing_time': 1613, 'target_landing_time': 1724, 'latest_landing_time': 3413, 'penalty_early': 1.66, 'penalty_late': 1.23}
# Plane 14: {'appearance_time': 1071, 'earliest_landing_time': 1671, 'target_landing_time': 1907, 'latest_landing_time': 3471, 'penalty_early': 1.61, 'penalty_late': 1.72}
# Plane 15: {'appearance_time': 1100, 'earliest_landing_time': 1700, 'target_landing_time': 2234, 'latest_landing_time': 3500, 'penalty_early': 1.78, 'penalty_late': 1.02}
# Plane 16: {'appearance_time': 1201, 'earliest_landing_time': 1801, 'target_landing_time': 2003, 'latest_landing_time': 3601, 'penalty_early': 1.09, 'penalty_late': 1.73}
# Plane 17: {'appearance_time': 1467, 'earliest_landing_time': 2067, 'target_landing_time': 2169, 'latest_landing_time': 3867, 'penalty_early': 1.85, 'penalty_late': 1.69}
# Plane 18: {'appearance_time': 1491, 'earliest_landing_time': 2091, 'target_landing_time': 2215, 'latest_landing_time': 3891, 'penalty_early': 1.89, 'penalty_late': 1.17}
# Plane 19: {'appearance_time': 1642, 'earliest_landing_time': 2242, 'target_landing_time': 2781, 'latest_landing_time': 4042, 'penalty_early': 1.3, 'penalty_late': 1.08}
# Plane 20: {'appearance_time': 1740, 'earliest_landing_time': 2340, 'target_landing_time': 2436, 'latest_landing_time': 4140, 'penalty_early': 1.67, 'penalty_late': 1.02}
# Plane 21: {'appearance_time': 2019, 'earliest_landing_time': 2619, 'target_landing_time': 3111, 'latest_landing_time': 4419, 'penalty_early': 1.02, 'penalty_late': 1.29}
# Plane 22: {'appearance_time': 2105, 'earliest_landing_time': 2705, 'target_landing_time': 2967, 'latest_landing_time': 4505, 'penalty_early': 1.26, 'penalty_late': 1.09}
# Plane 23: {'appearance_time': 2126, 'earliest_landing_time': 2726, 'target_landing_time': 2971, 'latest_landing_time': 4526, 'penalty_early': 1.7, 'penalty_late': 1.5}
# Plane 24: {'appearance_time': 2203, 'earliest_landing_time': 2803, 'target_landing_time': 2918, 'latest_landing_time': 4603, 'penalty_early': 1.08, 'penalty_late': 1.9}
# Plane 25: {'appearance_time': 2282, 'earliest_landing_time': 2882, 'target_landing_time': 3258, 'latest_landing_time': 4682, 'penalty_early': 1.58, 'penalty_late': 1.83}
# Plane 26: {'appearance_time': 2646, 'earliest_landing_time': 3246, 'target_landing_time': 3728, 'latest_landing_time': 5046, 'penalty_early': 1.08, 'penalty_late': 1.87}
# Plane 27: {'appearance_time': 2735, 'earliest_landing_time': 3335, 'target_landing_time': 3468, 'latest_landing_time': 5135, 'penalty_early': 1.14, 'penalty_late': 1.29}
# Plane 28: {'appearance_time': 2757, 'earliest_landing_time': 3357, 'target_landing_time': 3750, 'latest_landing_time': 5157, 'penalty_early': 1.2, 'penalty_late': 1.1}
# Plane 29: {'appearance_time': 2768, 'earliest_landing_time': 3368, 'target_landing_time': 3647, 'latest_landing_time': 5168, 'penalty_early': 1.55, 'penalty_late': 1.78}
# Plane 30: {'appearance_time': 2828, 'earliest_landing_time': 3428, 'target_landing_time': 3495, 'latest_landing_time': 5228, 'penalty_early': 1.2, 'penalty_late': 1.44}
# Plane 31: {'appearance_time': 2863, 'earliest_landing_time': 3463, 'target_landing_time': 3579, 'latest_landing_time': 5263, 'penalty_early': 1.27, 'penalty_late': 1.74}
# Plane 32: {'appearance_time': 2895, 'earliest_landing_time': 3495, 'target_landing_time': 4079, 'latest_landing_time': 5295, 'penalty_early': 1.97, 'penalty_late': 1.78}
# Plane 33: {'appearance_time': 2944, 'earliest_landing_time': 3544, 'target_landing_time': 3764, 'latest_landing_time': 5344, 'penalty_early': 1.38, 'penalty_late': 1.04}
# Plane 34: {'appearance_time': 3023, 'earliest_landing_time': 3623, 'target_landing_time': 3749, 'latest_landing_time': 5423, 'penalty_early': 1.66, 'penalty_late': 1.52}
# Plane 35: {'appearance_time': 3032, 'earliest_landing_time': 3632, 'target_landing_time': 3854, 'latest_landing_time': 5432, 'penalty_early': 1.88, 'penalty_late': 1.99}
# Plane 36: {'appearance_time': 3123, 'earliest_landing_time': 3723, 'target_landing_time': 4273, 'latest_landing_time': 5523, 'penalty_early': 1.56, 'penalty_late': 1.85}
# Plane 37: {'appearance_time': 3590, 'earliest_landing_time': 4190, 'target_landing_time': 4469, 'latest_landing_time': 5990, 'penalty_early': 1.2, 'penalty_late': 1.75}
# Plane 38: {'appearance_time': 3620, 'earliest_landing_time': 4220, 'target_landing_time': 4771, 'latest_landing_time': 6020, 'penalty_early': 1.94, 'penalty_late': 1.29}
# Plane 39: {'appearance_time': 3646, 'earliest_landing_time': 4246, 'target_landing_time': 4836, 'latest_landing_time': 6046, 'penalty_early': 1.99, 'penalty_late': 1.84}
# Plane 40: {'appearance_time': 3776, 'earliest_landing_time': 4376, 'target_landing_time': 4695, 'latest_landing_time': 6176, 'penalty_early': 1.3, 'penalty_late': 1.18}
# Plane 41: {'appearance_time': 3883, 'earliest_landing_time': 4483, 'target_landing_time': 4829, 'latest_landing_time': 6283, 'penalty_early': 1.67, 'penalty_late': 1.81}
# Plane 42: {'appearance_time': 4294, 'earliest_landing_time': 4894, 'target_landing_time': 5400, 'latest_landing_time': 6694, 'penalty_early': 1.3, 'penalty_late': 1.08}
# Plane 43: {'appearance_time': 4365, 'earliest_landing_time': 4965, 'target_landing_time': 5536, 'latest_landing_time': 6765, 'penalty_early': 1.2, 'penalty_late': 1.75}
# Plane 44: {'appearance_time': 4382, 'earliest_landing_time': 4982, 'target_landing_time': 5224, 'latest_landing_time': 6782, 'penalty_early': 1.57, 'penalty_late': 1.72}
# Plane 45: {'appearance_time': 4421, 'earliest_landing_time': 5021, 'target_landing_time': 5443, 'latest_landing_time': 6821, 'penalty_early': 1.57, 'penalty_late': 1.78}
# Plane 46: {'appearance_time': 4430, 'earliest_landing_time': 5030, 'target_landing_time': 5492, 'latest_landing_time': 6830, 'penalty_early': 1.22, 'penalty_late': 1.35}
# Plane 47: {'appearance_time': 4545, 'earliest_landing_time': 5145, 'target_landing_time': 5373, 'latest_landing_time': 6945, 'penalty_early': 1.7, 'penalty_late': 1.08}
# Plane 48: {'appearance_time': 4575, 'earliest_landing_time': 5175, 'target_landing_time': 5731, 'latest_landing_time': 6975, 'penalty_early': 1.99, 'penalty_late': 1.2}
# Plane 49: {'appearance_time': 4614, 'earliest_landing_time': 5214, 'target_landing_time': 5749, 'latest_landing_time': 7014, 'penalty_early': 1.19, 'penalty_late': 1.37}
# Plane 50: {'appearance_time': 4624, 'earliest_landing_time': 5224, 'target_landing_time': 5588, 'latest_landing_time': 7024, 'penalty_early': 1.13, 'penalty_late': 1.55}
# Plane 51: {'appearance_time': 4746, 'earliest_landing_time': 5346, 'target_landing_time': 5636, 'latest_landing_time': 7146, 'penalty_early': 1.61, 'penalty_late': 1.92}
# Plane 52: {'appearance_time': 4988, 'earliest_landing_time': 5588, 'target_landing_time': 5946, 'latest_landing_time': 7388, 'penalty_early': 1.46, 'penalty_late': 1.74}
# Plane 53: {'appearance_time': 5091, 'earliest_landing_time': 5691, 'target_landing_time': 6145, 'latest_landing_time': 7491, 'penalty_early': 1.97, 'penalty_late': 1.89}
# Plane 54: {'appearance_time': 5104, 'earliest_landing_time': 5704, 'target_landing_time': 6074, 'latest_landing_time': 7504, 'penalty_early': 1.75, 'penalty_late': 1.38}
# Plane 55: {'appearance_time': 5208, 'earliest_landing_time': 5808, 'target_landing_time': 6223, 'latest_landing_time': 7608, 'penalty_early': 1.61, 'penalty_late': 1.2}
# Plane 56: {'appearance_time': 5344, 'earliest_landing_time': 5944, 'target_landing_time': 6521, 'latest_landing_time': 7744, 'penalty_early': 1.89, 'penalty_late': 1.09}
# Plane 57: {'appearance_time': 5381, 'earliest_landing_time': 5981, 'target_landing_time': 6404, 'latest_landing_time': 7781, 'penalty_early': 1.17, 'penalty_late': 1.5}
# Plane 58: {'appearance_time': 5502, 'earliest_landing_time': 6102, 'target_landing_time': 6455, 'latest_landing_time': 7902, 'penalty_early': 1.47, 'penalty_late': 1.32}
# Plane 59: {'appearance_time': 5608, 'earliest_landing_time': 6208, 'target_landing_time': 6344, 'latest_landing_time': 8008, 'penalty_early': 1.44, 'penalty_late': 1.87}
# Plane 60: {'appearance_time': 5982, 'earliest_landing_time': 6582, 'target_landing_time': 6867, 'latest_landing_time': 8382, 'penalty_early': 1.39, 'penalty_late': 1.89}
# Plane 61: {'appearance_time': 6242, 'earliest_landing_time': 6842, 'target_landing_time': 6972, 'latest_landing_time': 8642, 'penalty_early': 1.8, 'penalty_late': 1.29}
# Plane 62: {'appearance_time': 6568, 'earliest_landing_time': 7168, 'target_landing_time': 7439, 'latest_landing_time': 8968, 'penalty_early': 1.8, 'penalty_late': 1.54}
# Plane 63: {'appearance_time': 6640, 'earliest_landing_time': 7240, 'target_landing_time': 7635, 'latest_landing_time': 9040, 'penalty_early': 1.07, 'penalty_late': 1.46}
# Plane 64: {'appearance_time': 6908, 'earliest_landing_time': 7508, 'target_landing_time': 7824, 'latest_landing_time': 9308, 'penalty_early': 1.82, 'penalty_late': 1.27}
# Plane 65: {'appearance_time': 7032, 'earliest_landing_time': 7632, 'target_landing_time': 8162, 'latest_landing_time': 9432, 'penalty_early': 1.55, 'penalty_late': 1.8}
# Plane 66: {'appearance_time': 7035, 'earliest_landing_time': 7635, 'target_landing_time': 8124, 'latest_landing_time': 9435, 'penalty_early': 1.49, 'penalty_late': 1.5}
# Plane 67: {'appearance_time': 7125, 'earliest_landing_time': 7725, 'target_landing_time': 8080, 'latest_landing_time': 9525, 'penalty_early': 1.37, 'penalty_late': 1.51}
# Plane 68: {'appearance_time': 7174, 'earliest_landing_time': 7774, 'target_landing_time': 8149, 'latest_landing_time': 9574, 'penalty_early': 1.65, 'penalty_late': 1.26}
# Plane 69: {'appearance_time': 7471, 'earliest_landing_time': 8071, 'target_landing_time': 8291, 'latest_landing_time': 9871, 'penalty_early': 1.8, 'penalty_late': 1.85}
# Plane 70: {'appearance_time': 7552, 'earliest_landing_time': 8152, 'target_landing_time': 8349, 'latest_landing_time': 9952, 'penalty_early': 1.73, 'penalty_late': 1.02}
# Plane 71: {'appearance_time': 7644, 'earliest_landing_time': 8244, 'target_landing_time': 8715, 'latest_landing_time': 10044, 'penalty_early': 1.96, 'penalty_late': 1.53}
# Plane 72: {'appearance_time': 7750, 'earliest_landing_time': 8350, 'target_landing_time': 8455, 'latest_landing_time': 10150, 'penalty_early': 1.74, 'penalty_late': 1.53}
# Plane 73: {'appearance_time': 8023, 'earliest_landing_time': 8623, 'target_landing_time': 8903, 'latest_landing_time': 10423, 'penalty_early': 1.77, 'penalty_late': 1.61}
# Plane 74: {'appearance_time': 8401, 'earliest_landing_time': 9001, 'target_landing_time': 9293, 'latest_landing_time': 10801, 'penalty_early': 1.54, 'penalty_late': 1.29}
# Plane 75: {'appearance_time': 8765, 'earliest_landing_time': 9365, 'target_landing_time': 9508, 'latest_landing_time': 11165, 'penalty_early': 1.48, 'penalty_late': 1.65}
# Plane 76: {'appearance_time': 8969, 'earliest_landing_time': 9569, 'target_landing_time': 9988, 'latest_landing_time': 11369, 'penalty_early': 1.62, 'penalty_late': 1.82}
# Plane 77: {'appearance_time': 9030, 'earliest_landing_time': 9630, 'target_landing_time': 9796, 'latest_landing_time': 11430, 'penalty_early': 1.73, 'penalty_late': 1.53}
# Plane 78: {'appearance_time': 9220, 'earliest_landing_time': 9820, 'target_landing_time': 10300, 'latest_landing_time': 11620, 'penalty_early': 1.76, 'penalty_late': 1.99}
# Plane 79: {'appearance_time': 9222, 'earliest_landing_time': 9822, 'target_landing_time': 10108, 'latest_landing_time': 11622, 'penalty_early': 1.76, 'penalty_late': 1.83}
# Plane 80: {'appearance_time': 9519, 'earliest_landing_time': 10119, 'target_landing_time': 10666, 'latest_landing_time': 11919, 'penalty_early': 1.61, 'penalty_late': 1.75}
# Plane 81: {'appearance_time': 9552, 'earliest_landing_time': 10152, 'target_landing_time': 10704, 'latest_landing_time': 11952, 'penalty_early': 1.72, 'penalty_late': 1.84}
# Plane 82: {'appearance_time': 9788, 'earliest_landing_time': 10388, 'target_landing_time': 10779, 'latest_landing_time': 12188, 'penalty_early': 1.97, 'penalty_late': 1.26}
# Plane 83: {'appearance_time': 9797, 'earliest_landing_time': 10397, 'target_landing_time': 10944, 'latest_landing_time': 12197, 'penalty_early': 1.21, 'penalty_late': 1.96}
# Plane 84: {'appearance_time': 9811, 'earliest_landing_time': 10411, 'target_landing_time': 10943, 'latest_landing_time': 12211, 'penalty_early': 1.05, 'penalty_late': 1.19}
# Plane 85: {'appearance_time': 9844, 'earliest_landing_time': 10444, 'target_landing_time': 10515, 'latest_landing_time': 12244, 'penalty_early': 1.06, 'penalty_late': 1.87}
# Plane 86: {'appearance_time': 10141, 'earliest_landing_time': 10741, 'target_landing_time': 11112, 'latest_landing_time': 12541, 'penalty_early': 1.74, 'penalty_late': 1.88}
# Plane 87: {'appearance_time': 10216, 'earliest_landing_time': 10816, 'target_landing_time': 11288, 'latest_landing_time': 12616, 'penalty_early': 1.39, 'penalty_late': 1.63}
# Plane 88: {'appearance_time': 10258, 'earliest_landing_time': 10858, 'target_landing_time': 11071, 'latest_landing_time': 12658, 'penalty_early': 1.14, 'penalty_late': 1.1}
# Plane 89: {'appearance_time': 10330, 'earliest_landing_time': 10930, 'target_landing_time': 11353, 'latest_landing_time': 12730, 'penalty_early': 1.49, 'penalty_late': 1.76}
# Plane 90: {'appearance_time': 10443, 'earliest_landing_time': 11043, 'target_landing_time': 11335, 'latest_landing_time': 12843, 'penalty_early': 1.91, 'penalty_late': 1.85}
# Plane 91: {'appearance_time': 10623, 'earliest_landing_time': 11223, 'target_landing_time': 11428, 'latest_landing_time': 13023, 'penalty_early': 1.0, 'penalty_late': 1.5}
# Plane 92: {'appearance_time': 10679, 'earliest_landing_time': 11279, 'target_landing_time': 11713, 'latest_landing_time': 13079, 'penalty_early': 1.84, 'penalty_late': 1.84}
# Plane 93: {'appearance_time': 10970, 'earliest_landing_time': 11570, 'target_landing_time': 11959, 'latest_landing_time': 13370, 'penalty_early': 1.53, 'penalty_late': 1.95}
# Plane 94: {'appearance_time': 11089, 'earliest_landing_time': 11689, 'target_landing_time': 12035, 'latest_landing_time': 13489, 'penalty_early': 1.02, 'penalty_late': 1.78}
# Plane 95: {'appearance_time': 11137, 'earliest_landing_time': 11737, 'target_landing_time': 12031, 'latest_landing_time': 13537, 'penalty_early': 1.73, 'penalty_late': 1.06}
# Plane 96: {'appearance_time': 11342, 'earliest_landing_time': 11942, 'target_landing_time': 12393, 'latest_landing_time': 13742, 'penalty_early': 1.44, 'penalty_late': 1.68}
# Plane 97: {'appearance_time': 11524, 'earliest_landing_time': 12124, 'target_landing_time': 12655, 'latest_landing_time': 13924, 'penalty_early': 1.79, 'penalty_late': 1.03}
# Plane 98: {'appearance_time': 11536, 'earliest_landing_time': 12136, 'target_landing_time': 12387, 'latest_landing_time': 13936, 'penalty_early': 1.99, 'penalty_late': 1.26}
# Plane 99: {'appearance_time': 11638, 'earliest_landing_time': 12238, 'target_landing_time': 12550, 'latest_landing_time': 14038, 'penalty_early': 1.03, 'penalty_late': 1.84}
# Plane 100: {'appearance_time': 11723, 'earliest_landing_time': 12323, 'target_landing_time': 12691, 'latest_landing_time': 14123, 'penalty_early': 1.71, 'penalty_late': 1.52}
#
# Separation times:
# After plane 1: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 2: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 3: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 4: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 5: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 6: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 7: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 8: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 9: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 10: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 11: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 12: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 13: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 14: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 15: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 16: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 17: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 18: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 19: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 20: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 21: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 22: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 23: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 24: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 25: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 26: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 27: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 28: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 29: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 30: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 31: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 32: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 33: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 34: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 35: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 36: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 37: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 38: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 39: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 40: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 41: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 42: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 43: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 44: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 45: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 46: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 47: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 48: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 49: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 50: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 51: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 52: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 53: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 54: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 55: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 56: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 57: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 58: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 59: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 60: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 61: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 62: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 63: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 64: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 65: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 66: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 67: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 68: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 69: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 70: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 71: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 72: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 73: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 74: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 75: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 76: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 77: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 78: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 79: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 80: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 81: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 82: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 83: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 84: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 85: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 86: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 87: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 88: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 89: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 90: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 91: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 92: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 93: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 94: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 95: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 96: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 97: [68, 68, 90, 68, 68, 68, 90, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 68, 68, 68, 68, 68, 90, 68, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 68, 68, 90, 90, 68, 68, 68, 68, 68, 90, 90, 90, 68, 68, 68, 90, 90, 68, 68, 90, 90, 68, 68, 90, 68, 68, 90, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 90, 68]
# After plane 98: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]
# After plane 99: [68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68, 68]
# After plane 100: [90, 90, 113, 113, 90, 90, 113, 90, 135, 113, 90, 90, 113, 113, 90, 113, 90, 90, 90, 90, 90, 113, 90, 135, 113, 113, 90, 113, 113, 113, 90, 135, 90, 90, 113, 113, 90, 90, 113, 90, 90, 135, 90, 90, 113, 113, 113, 90, 113, 113, 113, 90, 113, 113, 113, 113, 113, 90, 90, 90, 90, 113, 113, 113, 113, 90, 90, 113, 113, 113, 113, 113, 135, 113, 113, 90, 135, 90, 90, 113, 90, 113, 90, 113, 113, 90, 113, 113, 90, 90, 90, 90, 90, 113, 90, 113, 113, 90, 113, 90]

# %%
from ortools.sat.python import cp_model

def create_or_tools_cp_model_with_permutation(num_planes, num_runways, freeze_time, planes_data, separation_times):
    model = cp_model.CpModel()

    E = [p["earliest_landing_time"] for p in planes_data]
    T = [p["target_landing_time"] for p in planes_data]
    L = [p["latest_landing_time"] for p in planes_data]
    cost_e = [p["penalty_early"] for p in planes_data]
    cost_l = [p["penalty_late"] for p in planes_data]

    position = [model.NewIntVar(0, num_planes - 1, f"position_{i}") for i in range(num_planes)]
    model.AddAllDifferent(position)

    landing_time = [model.NewIntVar(0, 10000000, f"landing_time_{i}") for i in range(num_planes)]
    earliness = [model.NewIntVar(0, max(T[i] - E[i], 0), f"earliness_{i}") for i in range(num_planes)]
    lateness = [model.NewIntVar(0, max(L[i] - T[i], 0), f"lateness_{i}") for i in range(num_planes)]
    runway = [model.NewIntVar(0, num_runways - 1, f"runway_{i}") for i in range(num_planes)]

    for i in range(num_planes):
        model.Add(landing_time[i] >= E[i])
        model.Add(landing_time[i] <= L[i])
        model.Add(earliness[i] >= T[i] - landing_time[i])
        model.Add(earliness[i] >= 0)
        model.Add(lateness[i] >= landing_time[i] - T[i])
        model.Add(lateness[i] >= 0)

    for i in range(num_planes):
        for j in range(i + 1, num_planes):
            iBeforeJ = model.NewBoolVar(f"iBeforeJ_{i}_{j}")
            model.Add(position[i] < position[j]).OnlyEnforceIf(iBeforeJ)
            model.Add(position[i] >= position[j]).OnlyEnforceIf(iBeforeJ.Not())

            same_runway = model.NewBoolVar(f"same_runway_{i}_{j}")
            model.Add(runway[i] == runway[j]).OnlyEnforceIf(same_runway)
            model.Add(runway[i] != runway[j]).OnlyEnforceIf(same_runway.Not())

            model.Add(landing_time[j] >= landing_time[i] + separation_times[i][j]).OnlyEnforceIf(iBeforeJ).OnlyEnforceIf(same_runway)
            model.Add(landing_time[i] >= landing_time[j] + separation_times[j][i]).OnlyEnforceIf(iBeforeJ.Not()).OnlyEnforceIf(same_runway)

    cost_terms = []
    for i in range(num_planes):
        cost_terms.append(cost_e[i] * earliness[i])
        cost_terms.append(cost_l[i] * lateness[i])
    model.Minimize(sum(cost_terms))

    variables = {
        "position": position,
        "landing_time": landing_time,
        "earliness": earliness,
        "lateness": lateness,
        "runway": runway
    }

    return model, variables

def solve_cp_model_with_permutation(num_planes, num_runways, freeze_time, planes_data, separation_times, search_strategy):
    model, vars_ = create_or_tools_cp_model_with_permutation(num_planes, num_runways, freeze_time, planes_data, separation_times)

    solver = cp_model.CpSolver()

    # if search_strategy == "default":
    #     pass  # Use default search strategy
    # elif search_strategy == "min_conflicts":
    #     solver.parameters.search_branching = cp_model.VarBranchingPolicy.MIN_CONFLICTS
    # elif search_strategy == "first_fail":
    #     solver.parameters.search_branching = cp_model.VarBranchingPolicy.FIRST_FAIL
    # elif search_strategy == "automatic":
    #     solver.parameters.search_branching = cp_model.VarBranchingPolicy.AUTOMATIC
    # else:
    #     raise ValueError(f"Unknown search strategy: {search_strategy}")

    status = solver.Solve(model)

    if status in [cp_model.OPTIMAL, cp_model.FEASIBLE]:
        print("Status:", solver.StatusName(status))
        print("Objective (total earliness + lateness):", solver.ObjectiveValue())
        print()

        position = vars_["position"]
        landing_time = vars_["landing_time"]
        earliness = vars_["earliness"]
        lateness = vars_["lateness"]
        runway = vars_["runway"]

        for i in range(num_planes):
            pos_val = solver.Value(position[i])
            t_val = solver.Value(landing_time[i])
            e_ = solver.Value(earliness[i])
            L_ = solver.Value(lateness[i])
            T_ = planes_data[i]["target_landing_time"]
            r_ = solver.Value(runway[i])
            print(f"Plane {i}: position={pos_val}, landing={t_val}, runway={r_}, E'={e_}, L'={L_}, target={T_}")

        print("\nSchedule order (by position):")
        schedule = sorted(range(num_planes), key=lambda i: solver.Value(position[i]))
        for k in schedule:
            print(f" -> Plane {k} (pos={solver.Value(position[k])}, land={solver.Value(landing_time[k])}, runway={solver.Value(runway[k])})")

    else:
        print("No feasible/optimal solution found. Status:", solver.StatusName(status))

if __name__ == "__main__":
    num_runways = 2
    search_strategy = "min_conflicts"  # Example search strategy
    solve_cp_model_with_permutation(num_planes, num_runways, freeze_time, planes_data, separation_times, search_strategy)
# Out:
# Status: FEASIBLE
# Objective (total earliness + lateness): 5114.560000000001
#
# Plane 0: position=9, landing=908, runway=0, E'=0, L'=0, target=908
# Plane 1: position=13, landing=1027, runway=0, E'=0, L'=0, target=1027
# Plane 2: position=89, landing=1378, runway=0, E'=0, L'=0, target=1378
# Plane 3: position=91, landing=1550, runway=0, E'=0, L'=48, target=1502
# Plane 4: position=94, landing=1618, runway=0, E'=0, L'=0, target=1618
# Plane 5: position=74, landing=1235, runway=0, E'=0, L'=0, target=1235
# Plane 6: position=90, landing=1482, runway=0, E'=38, L'=0, target=1520
# Plane 7: position=1, landing=1411, runway=1, E'=0, L'=10, target=1401
# Plane 8: position=3, landing=1642, runway=1, E'=0, L'=58, target=1584
# Plane 9: position=0, landing=1343, runway=1, E'=0, L'=0, target=1343
# Plane 10: position=5, landing=1787, runway=1, E'=0, L'=0, target=1787
# Plane 11: position=2, landing=1507, runway=1, E'=193, L'=0, target=1700
# Plane 12: position=4, landing=1719, runway=1, E'=5, L'=0, target=1724
# Plane 13: position=6, landing=1907, runway=1, E'=0, L'=0, target=1907
# Plane 14: position=8, landing=2234, runway=1, E'=0, L'=0, target=2234
# Plane 15: position=7, landing=2003, runway=1, E'=0, L'=0, target=2003
# Plane 16: position=95, landing=2169, runway=0, E'=0, L'=0, target=2169
# Plane 17: position=10, landing=2324, runway=1, E'=0, L'=109, target=2215
# Plane 18: position=96, landing=2781, runway=0, E'=0, L'=0, target=2781
# Plane 19: position=11, landing=2436, runway=1, E'=0, L'=0, target=2436
# Plane 20: position=16, landing=3111, runway=1, E'=0, L'=0, target=3111
# Plane 21: position=14, landing=2953, runway=1, E'=14, L'=0, target=2967
# Plane 22: position=15, landing=3021, runway=1, E'=0, L'=50, target=2971
# Plane 23: position=12, landing=2885, runway=1, E'=33, L'=0, target=2918
# Plane 24: position=17, landing=3258, runway=1, E'=0, L'=0, target=3258
# Plane 25: position=21, landing=3675, runway=1, E'=53, L'=0, target=3728
# Plane 26: position=18, landing=3381, runway=1, E'=87, L'=0, target=3468
# Plane 27: position=23, landing=3811, runway=1, E'=0, L'=61, target=3750
# Plane 28: position=22, landing=3743, runway=1, E'=0, L'=96, target=3647
# Plane 29: position=19, landing=3494, runway=1, E'=1, L'=0, target=3495
# Plane 30: position=20, landing=3562, runway=1, E'=17, L'=0, target=3579
# Plane 31: position=27, landing=4172, runway=1, E'=0, L'=93, target=4079
# Plane 32: position=25, landing=3947, runway=1, E'=0, L'=184, target=3764
# Plane 33: position=26, landing=4037, runway=1, E'=0, L'=288, target=3749
# Plane 34: position=24, landing=3879, runway=1, E'=0, L'=25, target=3854
# Plane 35: position=28, landing=4273, runway=1, E'=0, L'=0, target=4273
# Plane 36: position=29, landing=4469, runway=1, E'=0, L'=0, target=4469
# Plane 37: position=31, landing=4723, runway=1, E'=48, L'=0, target=4771
# Plane 38: position=32, landing=4836, runway=1, E'=0, L'=0, target=4836
# Plane 39: position=30, landing=4633, runway=1, E'=62, L'=0, target=4695
# Plane 40: position=33, landing=4904, runway=1, E'=0, L'=75, target=4829
# Plane 41: position=36, landing=5323, runway=1, E'=77, L'=0, target=5400
# Plane 42: position=34, landing=5098, runway=1, E'=438, L'=0, target=5536
# Plane 43: position=35, landing=5188, runway=1, E'=36, L'=0, target=5224
# Plane 44: position=39, landing=5527, runway=1, E'=0, L'=84, target=5443
# Plane 45: position=38, landing=5459, runway=1, E'=33, L'=0, target=5492
# Plane 46: position=37, landing=5391, runway=1, E'=0, L'=18, target=5373
# Plane 47: position=42, landing=5731, runway=1, E'=0, L'=0, target=5731
# Plane 48: position=43, landing=5844, runway=1, E'=0, L'=95, target=5749
# Plane 49: position=41, landing=5663, runway=1, E'=0, L'=75, target=5588
# Plane 50: position=40, landing=5595, runway=1, E'=41, L'=0, target=5636
# Plane 51: position=44, landing=5946, runway=1, E'=0, L'=0, target=5946
# Plane 52: position=45, landing=6087, runway=1, E'=58, L'=0, target=6145
# Plane 53: position=46, landing=6155, runway=1, E'=0, L'=81, target=6074
# Plane 54: position=47, landing=6223, runway=1, E'=0, L'=0, target=6223
# Plane 55: position=51, landing=6585, runway=1, E'=0, L'=64, target=6521
# Plane 56: position=49, landing=6404, runway=1, E'=0, L'=0, target=6404
# Plane 57: position=50, landing=6472, runway=1, E'=0, L'=17, target=6455
# Plane 58: position=48, landing=6291, runway=1, E'=53, L'=0, target=6344
# Plane 59: position=52, landing=6867, runway=1, E'=0, L'=0, target=6867
# Plane 60: position=53, landing=6972, runway=1, E'=0, L'=0, target=6972
# Plane 61: position=54, landing=7439, runway=1, E'=0, L'=0, target=7439
# Plane 62: position=55, landing=7635, runway=1, E'=0, L'=0, target=7635
# Plane 63: position=56, landing=7824, runway=1, E'=0, L'=0, target=7824
# Plane 64: position=58, landing=8057, runway=1, E'=105, L'=0, target=8162
# Plane 65: position=59, landing=8125, runway=1, E'=0, L'=1, target=8124
# Plane 66: position=57, landing=7944, runway=1, E'=136, L'=0, target=8080
# Plane 67: position=61, landing=8306, runway=1, E'=0, L'=157, target=8149
# Plane 68: position=60, landing=8238, runway=1, E'=53, L'=0, target=8291
# Plane 69: position=62, landing=8396, runway=1, E'=0, L'=47, target=8349
# Plane 70: position=64, landing=8715, runway=1, E'=0, L'=0, target=8715
# Plane 71: position=63, landing=8464, runway=1, E'=0, L'=9, target=8455
# Plane 72: position=65, landing=8903, runway=1, E'=0, L'=0, target=8903
# Plane 73: position=66, landing=9293, runway=1, E'=0, L'=0, target=9293
# Plane 74: position=67, landing=9508, runway=1, E'=0, L'=0, target=9508
# Plane 75: position=69, landing=9988, runway=1, E'=0, L'=0, target=9988
# Plane 76: position=68, landing=9796, runway=1, E'=0, L'=0, target=9796
# Plane 77: position=71, landing=10300, runway=1, E'=0, L'=0, target=10300
# Plane 78: position=70, landing=10108, runway=1, E'=0, L'=0, target=10108
# Plane 79: position=73, landing=10666, runway=1, E'=0, L'=0, target=10666
# Plane 80: position=97, landing=10704, runway=0, E'=0, L'=0, target=10704
# Plane 81: position=75, landing=10779, runway=1, E'=0, L'=0, target=10779
# Plane 82: position=77, landing=10944, runway=1, E'=0, L'=0, target=10944
# Plane 83: position=76, landing=10876, runway=1, E'=67, L'=0, target=10943
# Plane 84: position=72, landing=10515, runway=1, E'=0, L'=0, target=10515
# Plane 85: position=78, landing=11107, runway=1, E'=5, L'=0, target=11112
# Plane 86: position=80, landing=11288, runway=1, E'=0, L'=0, target=11288
# Plane 87: position=79, landing=11220, runway=1, E'=0, L'=149, target=11071
# Plane 88: position=81, landing=11356, runway=1, E'=0, L'=3, target=11353
# Plane 89: position=98, landing=11335, runway=0, E'=0, L'=0, target=11335
# Plane 90: position=99, landing=11428, runway=0, E'=0, L'=0, target=11428
# Plane 91: position=82, landing=11713, runway=1, E'=0, L'=0, target=11713
# Plane 92: position=83, landing=11922, runway=1, E'=37, L'=0, target=11959
# Plane 93: position=84, landing=12035, runway=1, E'=0, L'=0, target=12035
# Plane 94: position=85, landing=12103, runway=1, E'=0, L'=72, target=12031
# Plane 95: position=86, landing=12369, runway=1, E'=24, L'=0, target=12393
# Plane 96: position=92, landing=12655, runway=1, E'=0, L'=0, target=12655
# Plane 97: position=87, landing=12437, runway=1, E'=0, L'=50, target=12387
# Plane 98: position=88, landing=12550, runway=1, E'=0, L'=0, target=12550
# Plane 99: position=93, landing=12723, runway=1, E'=0, L'=32, target=12691
#
# Schedule order (by position):
#  -> Plane 9 (pos=0, land=1343, runway=1)
#  -> Plane 7 (pos=1, land=1411, runway=1)
#  -> Plane 11 (pos=2, land=1507, runway=1)
#  -> Plane 8 (pos=3, land=1642, runway=1)
#  -> Plane 12 (pos=4, land=1719, runway=1)
#  -> Plane 10 (pos=5, land=1787, runway=1)
#  -> Plane 13 (pos=6, land=1907, runway=1)
#  -> Plane 15 (pos=7, land=2003, runway=1)
#  -> Plane 14 (pos=8, land=2234, runway=1)
#  -> Plane 0 (pos=9, land=908, runway=0)
#  -> Plane 17 (pos=10, land=2324, runway=1)
#  -> Plane 19 (pos=11, land=2436, runway=1)
#  -> Plane 23 (pos=12, land=2885, runway=1)
#  -> Plane 1 (pos=13, land=1027, runway=0)
#  -> Plane 21 (pos=14, land=2953, runway=1)
#  -> Plane 22 (pos=15, land=3021, runway=1)
#  -> Plane 20 (pos=16, land=3111, runway=1)
#  -> Plane 24 (pos=17, land=3258, runway=1)
#  -> Plane 26 (pos=18, land=3381, runway=1)
#  -> Plane 29 (pos=19, land=3494, runway=1)
#  -> Plane 30 (pos=20, land=3562, runway=1)
#  -> Plane 25 (pos=21, land=3675, runway=1)
#  -> Plane 28 (pos=22, land=3743, runway=1)
#  -> Plane 27 (pos=23, land=3811, runway=1)
#  -> Plane 34 (pos=24, land=3879, runway=1)
#  -> Plane 32 (pos=25, land=3947, runway=1)
#  -> Plane 33 (pos=26, land=4037, runway=1)
#  -> Plane 31 (pos=27, land=4172, runway=1)
#  -> Plane 35 (pos=28, land=4273, runway=1)
#  -> Plane 36 (pos=29, land=4469, runway=1)
#  -> Plane 39 (pos=30, land=4633, runway=1)
#  -> Plane 37 (pos=31, land=4723, runway=1)
#  -> Plane 38 (pos=32, land=4836, runway=1)
#  -> Plane 40 (pos=33, land=4904, runway=1)
#  -> Plane 42 (pos=34, land=5098, runway=1)
#  -> Plane 43 (pos=35, land=5188, runway=1)
#  -> Plane 41 (pos=36, land=5323, runway=1)
#  -> Plane 46 (pos=37, land=5391, runway=1)
#  -> Plane 45 (pos=38, land=5459, runway=1)
#  -> Plane 44 (pos=39, land=5527, runway=1)
#  -> Plane 50 (pos=40, land=5595, runway=1)
#  -> Plane 49 (pos=41, land=5663, runway=1)
#  -> Plane 47 (pos=42, land=5731, runway=1)
#  -> Plane 48 (pos=43, land=5844, runway=1)
#  -> Plane 51 (pos=44, land=5946, runway=1)
#  -> Plane 52 (pos=45, land=6087, runway=1)
#  -> Plane 53 (pos=46, land=6155, runway=1)
#  -> Plane 54 (pos=47, land=6223, runway=1)
#  -> Plane 58 (pos=48, land=6291, runway=1)
#  -> Plane 56 (pos=49, land=6404, runway=1)
#  -> Plane 57 (pos=50, land=6472, runway=1)
#  -> Plane 55 (pos=51, land=6585, runway=1)
#  -> Plane 59 (pos=52, land=6867, runway=1)
#  -> Plane 60 (pos=53, land=6972, runway=1)
#  -> Plane 61 (pos=54, land=7439, runway=1)
#  -> Plane 62 (pos=55, land=7635, runway=1)
#  -> Plane 63 (pos=56, land=7824, runway=1)
#  -> Plane 66 (pos=57, land=7944, runway=1)
#  -> Plane 64 (pos=58, land=8057, runway=1)
#  -> Plane 65 (pos=59, land=8125, runway=1)
#  -> Plane 68 (pos=60, land=8238, runway=1)
#  -> Plane 67 (pos=61, land=8306, runway=1)
#  -> Plane 69 (pos=62, land=8396, runway=1)
#  -> Plane 71 (pos=63, land=8464, runway=1)
#  -> Plane 70 (pos=64, land=8715, runway=1)
#  -> Plane 72 (pos=65, land=8903, runway=1)
#  -> Plane 73 (pos=66, land=9293, runway=1)
#  -> Plane 74 (pos=67, land=9508, runway=1)
#  -> Plane 76 (pos=68, land=9796, runway=1)
#  -> Plane 75 (pos=69, land=9988, runway=1)
#  -> Plane 78 (pos=70, land=10108, runway=1)
#  -> Plane 77 (pos=71, land=10300, runway=1)
#  -> Plane 84 (pos=72, land=10515, runway=1)
#  -> Plane 79 (pos=73, land=10666, runway=1)
#  -> Plane 5 (pos=74, land=1235, runway=0)
#  -> Plane 81 (pos=75, land=10779, runway=1)
#  -> Plane 83 (pos=76, land=10876, runway=1)
#  -> Plane 82 (pos=77, land=10944, runway=1)
#  -> Plane 85 (pos=78, land=11107, runway=1)
#  -> Plane 87 (pos=79, land=11220, runway=1)
#  -> Plane 86 (pos=80, land=11288, runway=1)
#  -> Plane 88 (pos=81, land=11356, runway=1)
#  -> Plane 91 (pos=82, land=11713, runway=1)
#  -> Plane 92 (pos=83, land=11922, runway=1)
#  -> Plane 93 (pos=84, land=12035, runway=1)
#  -> Plane 94 (pos=85, land=12103, runway=1)
#  -> Plane 95 (pos=86, land=12369, runway=1)
#  -> Plane 97 (pos=87, land=12437, runway=1)
#  -> Plane 98 (pos=88, land=12550, runway=1)
#  -> Plane 2 (pos=89, land=1378, runway=0)
#  -> Plane 6 (pos=90, land=1482, runway=0)
#  -> Plane 3 (pos=91, land=1550, runway=0)
#  -> Plane 96 (pos=92, land=12655, runway=1)
#  -> Plane 99 (pos=93, land=12723, runway=1)
#  -> Plane 4 (pos=94, land=1618, runway=0)
#  -> Plane 16 (pos=95, land=2169, runway=0)
#  -> Plane 18 (pos=96, land=2781, runway=0)
#  -> Plane 80 (pos=97, land=10704, runway=0)
#  -> Plane 89 (pos=98, land=11335, runway=0)
#  -> Plane 90 (pos=99, land=11428, runway=0)
